# %% [markdown]
# # Logit lens (defect)

# %%
import torch
from PIL import Image
import matplotlib.pyplot as plt
import seaborn as sns
from transformers import AutoModelForCausalLM, AutoConfig
from transformers import AutoProcessor
from torchvision.transforms import Resize, ToTensor, Normalize, Compose

# Load the Ovis2-8B model from Hugging Face
config = AutoConfig.from_pretrained(
    "AIDC-AI/Ovis2-8B",
    trust_remote_code=True)

config.llm_attn_implementation = "eager" 

model = AutoModelForCausalLM.from_pretrained(
    "AIDC-AI/Ovis2-8B",
    config=config, 
    torch_dtype=torch.bfloat16,
    multimodal_max_length=32768,
    trust_remote_code=True,
    attn_implementation="eager" 
).cuda()

# Get the text and visual tokenizers
text_tokenizer = model.get_text_tokenizer()
visual_tokenizer = model.get_visual_tokenizer()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 10
#       7 from torchvision.transforms import Resize, ToTensor, Normalize, Compose
#       9 # Load the Ovis2-8B model from Hugging Face
# ---> 10 config = AutoConfig.from_pretrained(
#      11     "AIDC-AI/Ovis2-8B",
#      12     trust_remote_code=True)
#      14 config.llm_attn_implementation = "eager"
#      16 model = AutoModelForCausalLM.from_pretrained(
#      17     "AIDC-AI/Ovis2-8B",
#      18     config=config,
#    (...)
#      22     attn_implementation="eager"
#      23 ).cuda()
#
# File ~/.local/lib/python3.11/site-packages/transformers/models/auto/configuration_auto.py:1063, in AutoConfig.from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#    1061 if has_remote_code and trust_remote_code:
#    1062     class_ref = config_dict["auto_map"]["AutoConfig"]
# -> 1063     config_class = get_class_from_dynamic_module(
#    1064         class_ref, pretrained_model_name_or_path, code_revision=code_revision, **kwargs
#    1065     )
#    1066     if os.path.isdir(pretrained_model_name_or_path):
#    1067         config_class.register_for_auto_class()
#
# File ~/.local/lib/python3.11/site-packages/transformers/dynamic_module_utils.py:553, in get_class_from_dynamic_module(class_reference, pretrained_model_name_or_path, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, repo_type, code_revision, **kwargs)
#     540 # And lastly we get the class inside our newly created module
#     541 final_module = get_cached_module_file(
#     542     repo_id,
#     543     module_file + ".py",
#    (...)
#     551     repo_type=repo_type,
#     552 )
# --> 553 return get_class_in_module(class_name, final_module, force_reload=force_download)
#
# File ~/.local/lib/python3.11/site-packages/transformers/dynamic_module_utils.py:250, in get_class_in_module(class_name, module_path, force_reload)
#     248 # reload in both cases, unless the module is already imported and the hash hits
#     249 if getattr(module, "__transformers_module_hash__", "") != module_hash:
# --> 250     module_spec.loader.exec_module(module)
#     251     module.__transformers_module_hash__ = module_hash
#     252 return getattr(module, class_name)
#
# File <frozen importlib._bootstrap_external>:940, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~/.cache/huggingface/modules/transformers_modules/AIDC-AI/Ovis2-8B/d0e09dbe6ce98dc788491976d3c69a539012d44f/configuration_ovis.py:6
#       4 from transformers import PretrainedConfig, AutoConfig, AutoModel
#       5 from .configuration_aimv2 import AIMv2Config
# ----> 6 from .modeling_aimv2 import AIMv2Model
#       8 IGNORE_ID = -100
#       9 IMAGE_TOKEN_ID = -200
#
# File ~/.cache/huggingface/modules/transformers_modules/AIDC-AI/Ovis2-8B/d0e09dbe6ce98dc788491976d3c69a539012d44f/modeling_aimv2.py:9
#       7 from torch.nn import functional as F
#       8 from transformers.modeling_outputs import BaseModelOutputWithNoAttention
# ----> 9 from transformers.modeling_utils import PreTrainedModel
#      11 __all__ = ["AIMv2Model"]
#      14 class RMSNorm(nn.Module):
#
# File ~/.local/lib/python3.11/site-packages/transformers/modeling_utils.py:51
#      49 from .integrations.flex_attention import flex_attention_forward
#      50 from .integrations.sdpa_attention import sdpa_attention_forward
# ---> 51 from .loss.loss_utils import LOSS_MAPPING
#      52 from .pytorch_utils import (  # noqa: F401
#      53     Conv1D,
#      54     apply_chunking_to_forward,
#    (...)
#      60     translate_to_torch_parallel_style,
#      61 )
#      62 from .quantizers import AutoHfQuantizer, HfQuantizer
#
# File <frozen importlib._bootstrap>:1178, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1149, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:690, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:936, in exec_module(self, module)
#
# File <frozen importlib._bootstrap_external>:1032, in get_code(self, fullname)
#
# File <frozen importlib._bootstrap_external>:1130, in get_data(self, path)
#
# KeyboardInterrupt:

# %%
# Prepare the input: image and text prompt
image_path = '/home/bboulbarss/large_dataset/relational/train/cone_right_cylinder/CLEVR_rel_000020.png'
image = Image.open(image_path).convert('RGB')
text = "Task: Identify the correct label for this image from the following choices:\nA. A photo of a cone right of a cylinder\nB. A photo of a blue cube\nC. A photo of a red sphere\nAnswer with the letter of the correct choice."
query = f'\n{text}'
print(query)

# %%
# Manually preprocess the image to match expected size
transform = Compose([
    Resize((224, 224)),  # Adjust to 336x336 or 448x448 if model config specifies
    ToTensor(),
    Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])
pixel_values = transform(image).unsqueeze(0).to(dtype=torch.bfloat16, device=model.device)

# Verify pixel_values shape
if pixel_values.shape[1] != 3:
    raise ValueError(f"pixel_values has {pixel_values.shape[1]} channels, expected 3 (RGB).")

# Manually preprocess text to ensure valid input_ids and attention_mask
text_inputs = text_tokenizer(query, return_tensors="pt", padding=True)
input_ids = text_inputs['input_ids'].to(model.device)
attention_mask = text_inputs['attention_mask'].to(model.device)

# Verify input shapes before passing to model
print(f"input_ids shape: {input_ids.shape}")
print(f"attention_mask shape: {attention_mask.shape}")
print(f"pixel_values shape: {pixel_values.shape}")

# Function to get layer-wise logits
def get_layer_logits(model, input_ids, pixel_values, attention_mask):
    with torch.no_grad():
        outputs = model(
            input_ids=input_ids,
            pixel_values=[pixel_values],  # Wrap in list for merge_multimodal
            attention_mask=attention_mask,
            output_hidden_states=True,
            labels=None  # Explicitly pass None for inference
        )
    hidden_states = outputs.hidden_states
    lm_head = model.llm.lm_head  # Access lm_head via llm submodule
    layer_logits = [lm_head(hs) for hs in hidden_states]
    return layer_logits


# Get the layer-wise logits
layer_logits = get_layer_logits(model, input_ids, pixel_values, attention_mask)

# Analyze logits: Get top-1 predicted tokens and probabilities
predicted_tokens = [logits.argmax(dim=-1)[0].cpu().numpy() for logits in layer_logits]
probs = [torch.softmax(logits, dim=-1).max(dim=-1).values[0].float().detach().cpu().numpy() for logits in layer_logits]

# Decode predicted tokens to strings
decoded_tokens = []
for layer_preds in predicted_tokens:
    layer_decoded = [text_tokenizer.decode([token_id]) for token_id in layer_preds]
    decoded_tokens.append(layer_decoded)

# Print shapes and sample predictions for verification
for i, (logits, layer_preds) in enumerate(zip(layer_logits, decoded_tokens)):
    print(f"Layer {i} logits shape: {logits.shape}")
    print(f"Layer {i} top-1 tokens (first 5 positions): {layer_preds[:5]}")

# Basic visualization: Heatmap of top-1 probabilities across layers
def plot_token_progress(probs, start_idx=0, end_idx=10):
    # Slice probabilities for specified token positions
    probs_array = [p[start_idx:end_idx] for p in probs]
    plt.figure(figsize=(10, 6))
    sns.heatmap(probs_array, cmap="Blues", annot=True, fmt=".2f", cbar_kws={'label': 'Top-1 Probability'})
    plt.title("Top-1 Probability Across Layers")
    plt.xlabel("Token Position")
    plt.ylabel("Layer")
    plt.yticks(ticks=range(len(probs)), labels=[f"Layer {i}" for i in range(len(probs))], rotation=0)
    plt.show()

# Plot probabilities for the first 10 tokens
plot_token_progress(probs, start_idx=0, end_idx=10)

# %% [markdown]
# # Logit lens (works, old)

# %%
import torch
from transformers import AutoModelForCausalLM, AutoConfig
from PIL import Image

# Load the model configuration and model
config = AutoConfig.from_pretrained("AIDC-AI/Ovis2-8B", trust_remote_code=True)
config.llm_attn_implementation = "eager"

model = AutoModelForCausalLM.from_pretrained(
    "AIDC-AI/Ovis2-8B",
    config=config,
    multimodal_max_length=32768,
    trust_remote_code=True,
    attn_implementation="eager"
).cuda()

# Get tokenizers
text_tokenizer = model.get_text_tokenizer()
visual_tokenizer = model.get_visual_tokenizer()

# Load image and define query
image_path = '/home/bboulbarss/large_dataset/relational/train/cone_right_cylinder/CLEVR_rel_000020.png'
image = Image.open(image_path).convert("RGB")
images = [image]
#text = 'Describe this image'
text = "Task: Identify the correct label for this image from the following choices:\nA. A photo of a blue cube\nB. A photo of a red sphere\nC. A photo of a cone right of a cylinder\nAnswer with the letter of the correct choice."
query = f"\n{text}"

# Preprocess inputs
prompt, input_ids, pixel_values = model.preprocess_inputs(query, images)
attention_mask = torch.ne(input_ids, text_tokenizer.pad_token_id)

# Move to GPU
input_ids = input_ids.unsqueeze(0).to(model.device)
attention_mask = attention_mask.unsqueeze(0).to(model.device)
if pixel_values is not None:
    pixel_values = pixel_values.to(dtype=visual_tokenizer.dtype, device=visual_tokenizer.device)
    pixel_values = [pixel_values]

# Run model with output_hidden_states=True to get hidden states from each layer
outputs = model(input_ids=input_ids, pixel_values=pixel_values, attention_mask=attention_mask, output_hidden_states=True, labels=None)
hidden_states = outputs.hidden_states  # List of tensors: [1, seq_len, hidden_size]

# Get the language modeling head
lm_head = model.llm.lm_head  # Changed from model.lm_head

# Rest of the code remains the same
# Determine sequence lengths
full_seq_len = hidden_states[0].shape[1]  # Total sequence length (image + text tokens)
text_seq_len = input_ids.shape[1]  # Length of text tokens (e.g., 7 for the prompt)
text_positions = slice(full_seq_len - text_seq_len, full_seq_len)  # Slice for text positions

# Define a safe decode function to handle out-of-range token IDs
def safe_decode(token_id):
    try:
        return text_tokenizer.convert_ids_to_tokens([token_id])[0]
    except IndexError:
        return f"[SPECIAL_{token_id}]"

# Apply the logit lens
print("Applying logit lens to the text sequence:")
for layer_idx, hidden_state in enumerate(hidden_states):
    print(f"\nLayer {layer_idx}:")
    # Extract hidden states for text positions only
    text_hidden_state = hidden_state[:, text_positions, :]  # [1, text_seq_len, hidden_size]
    logits = lm_head(text_hidden_state)  # [1, text_seq_len, vocab_size]
    
    # Get top-5 token predictions for each position
    topk_tokens = torch.topk(logits, k=5, dim=-1).indices[0]  # [text_seq_len, 5]
    
    for pos in range(text_seq_len):
        #if pos == 0:
            top_tokens = [safe_decode(token_id.item()) for token_id in topk_tokens[pos]]
            print(f"  Position {pos}: {top_tokens}")

# %% [markdown]
# # Generate predictions

# %%
from transformers import AutoModelForCausalLM, AutoConfig
import torch
from PIL import Image

# Load the model configuration
config = AutoConfig.from_pretrained("AIDC-AI/Ovis2-8B", trust_remote_code=True)
config.llm_attn_implementation = "eager"  # Use eager attention

# Load the model
model = AutoModelForCausalLM.from_pretrained(
    "AIDC-AI/Ovis2-8B",
    config=config,
    multimodal_max_length=32768,
    trust_remote_code=True,
    attn_implementation="eager"
).cuda()

# Get tokenizers from the model
text_tokenizer = model.get_text_tokenizer()
visual_tokenizer = model.get_visual_tokenizer()

image_path = '/home/bboulbarss/large_dataset/relational/train/cone_right_cylinder/CLEVR_rel_000020.png'
image = Image.open(image_path).convert("RGB")
images = [image]  # Wrap in a list as preprocess_inputs expects a list of images

#text = "Task: Identify the correct label for this image from the following choices:\nA. A photo of a cone right of a cylinder\nB. A photo of a blue cube\nC. A photo of a red sphere\nAnswer with the letter of the correct choice."
text = "Describe this image."
query = f'\n{text}'
print(query)

# Preprocess inputs using the model's function
prompt, input_ids, pixel_values = model.preprocess_inputs(query, images)

# Create attention mask
attention_mask = torch.ne(input_ids, text_tokenizer.pad_token_id)

# Prepare inputs for the model
input_ids = input_ids.unsqueeze(0).to(device=model.device)
attention_mask = attention_mask.unsqueeze(0).to(device=model.device)
if pixel_values is not None:
    pixel_values = pixel_values.to(dtype=visual_tokenizer.dtype, device=visual_tokenizer.device)
    pixel_values = [pixel_values]  # Wrap in a list if required by the model
# Out:
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Describe this image.

# %%
# Define generation parameters
gen_kwargs = {
    "max_new_tokens": 200,
    "do_sample": False,
    "eos_token_id": model.generation_config.eos_token_id,
    "pad_token_id": text_tokenizer.pad_token_id,
    "use_cache": True
}

# Generate output
with torch.inference_mode():
    output_ids = model.generate(
        input_ids,
        pixel_values=pixel_values,
        attention_mask=attention_mask,
        **gen_kwargs
    )[0]

# Decode the output
generated_text = text_tokenizer.decode(output_ids, skip_special_tokens=True).strip()
print(generated_text)
# Out:
# The image shows a simple 3D scene with a purple cylinder and a green cone placed on a flat surface. The background is a neutral gray, providing a contrast that highlights the objects. The lighting is soft and diffused, casting gentle shadows to the right of the objects, suggesting a light source from the left. The scene is minimalistic, with no additional elements or context provided.

# %% [markdown]
# # Logit lens (newest version)

# %%
#import torch
from transformers import AutoModelForCausalLM, AutoConfig
from PIL import Image
import torch
from PIL import Image
import matplotlib.pyplot as plt
import seaborn as sns
from transformers import AutoModelForCausalLM, AutoConfig
from transformers import AutoProcessor
from torchvision.transforms import Resize, ToTensor, Normalize, Compose

# Load the model configuration and model
config = AutoConfig.from_pretrained("AIDC-AI/Ovis2-8B", trust_remote_code=True)
config.llm_attn_implementation = "eager"

model = AutoModelForCausalLM.from_pretrained(
    "AIDC-AI/Ovis2-8B",
    config=config,
    multimodal_max_length=32768,
    trust_remote_code=True,
    attn_implementation="eager"
).cuda()

# Get the language modeling head
lm_head = model.llm.lm_head

# Get tokenizers
text_tokenizer = model.get_text_tokenizer()
visual_tokenizer = model.get_visual_tokenizer()

# Load image and define query
image_path = '/home/bboulbarss/large_dataset/relational/train/cone_right_cylinder/CLEVR_rel_000020.png'
image = Image.open(image_path).convert("RGB")

#image_path2 = '/home/bboulbarss/large_dataset/relational/train/cube_left_sphere/CLEVR_rel_000043.png'
#image2 = Image.open(image_path2).convert("RGB")
images = [image]
#text = 'Describe this image'
text = "Task: Identify the correct label for this image from the following choices:\nA. A photo of a cylinder right of a cone\nB. A photo of a cone right of a cylinder\nC. A photo of a cone left of a cylinder\nAnswer with the letter of the correct choice."
#text = 'Describe this image. The Image shows a green cone right of a purple cylinder.'
#text1 = 'This is a photo of a cone right of a cylinder'
#text2 = 'This is a photo of a cube left of a sphere'
query = f"\n{text}"

# Preprocess inputs
prompt, input_ids, pixel_values = model.preprocess_inputs(query, images)
attention_mask = torch.ne(input_ids, text_tokenizer.pad_token_id)

# Move to GPU
input_ids = input_ids.unsqueeze(0).to(model.device)
attention_mask = attention_mask.unsqueeze(0).to(model.device)
if pixel_values is not None:
    pixel_values = pixel_values.to(dtype=visual_tokenizer.dtype, device=visual_tokenizer.device)
    pixel_values = [pixel_values]

# After model forward pass
outputs = model(input_ids=input_ids, pixel_values=pixel_values, attention_mask=attention_mask, output_hidden_states=True, labels=None)
hidden_states = outputs.hidden_states  # List of [1, full_seq_len, hidden_size]

# Define text sequence length and positions
text_seq_len = input_ids.shape[1]
full_seq_len = hidden_states[0].shape[1]
text_positions = slice(full_seq_len - text_seq_len, full_seq_len)

# Define the safe decoding function
def safe_decode(token_ids, tokenizer):
    tokens = []
    vocab_size = tokenizer.vocab_size
    for token_id in token_ids:
        if token_id < 0 or token_id >= vocab_size:
            tokens.append(f"[SPECIAL_{token_id}]")
        else:
            tokens.append(tokenizer.convert_ids_to_tokens([token_id])[0])
    return tokens

# Decode correct tokens
text_input_ids = input_ids[0].cpu().tolist()  # [text_seq_len]
###
# After getting input_ids
#text_input_ids = input_ids[0].cpu().tolist()
#print("text_input_ids:", text_input_ids)
#print("Unique token IDs:", sorted(set(text_input_ids)))
#print("Pad token ID:", text_tokenizer.pad_token_id)
#print("Vocab size:", text_tokenizer.vocab_size)
###


correct_tokens = safe_decode(text_input_ids, text_tokenizer)

# Logit lens analysis across layers
for layer_idx, hidden_state in enumerate(hidden_states):
    print(f"\nLayer {layer_idx}:")
    # Extract hidden states for text positions only
    text_hidden_state = hidden_state[:, text_positions, :]  # [1, text_seq_len, hidden_size]
    logits = lm_head(text_hidden_state)  # [1, text_seq_len, vocab_size]
    
    # Get top-5 token predictions for each position
    topk_tokens = torch.topk(logits, k=5, dim=-1).indices[0]  # [text_seq_len, 5]
    
    # Print correct token and top-5 predictions for each position
    for pos in range(text_seq_len):
        top_tokens = safe_decode(topk_tokens[pos].tolist(), text_tokenizer)
        correct_token = correct_tokens[pos]
        correct_display = f"(Correct: '{correct_token}')"
        print(f"  Position {pos} {correct_display:<25} {top_tokens}")
# Out:
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
#
#   Position 46 (Correct: '.')            ['æį¢åı¥è¯Ŀ', 'peater', 'Ġëĭ¤ë§Į', 'oins', '/lg']
#   Position 47 (Correct: 'ĠA')           ['Ð¸ÑĩÐµÑģ', 'antlr', 'ç©¹', 'getto', 'å¦ª']
#   Position 48 (Correct: 'Ġphoto')       ['ium', 'ioneer', 'asmus', 'urniture', '>>)']
#   Position 49 (Correct: 'Ġof')          ['scribe', 'voluciÃ³n', 'rive', 'ispens', 'udit']
#   Position 50 (Correct: 'Ġa')           ['Ø£ÙĪØ¶', 'ÑģÑĤÑĢÐ°Ð¸Ð²Ð°', 'ĠhÃ¼', 'entiful', 'SharedPtr']
#   Position 51 (Correct: 'Ġcone')        ['ILLISECONDS', 'ç®¡å§Ķä¼ļ', 'pcodes', 'Ð©', ')||(']
#   Position 52 (Correct: 'Ġright')       ['rowse', 'į°ìĿ´', 'ç§ĳçłĶéĻ¢', 'éĴī', 'ueil']
#   Position 53 (Correct: 'Ġof')          ['scribe', 'voluciÃ³n', 'rive', 'ispens', 'udit']
#   Position 54 (Correct: 'Ġa')           ['Ø£ÙĪØ¶', 'ÑģÑĤÑĢÐ°Ð¸Ð²Ð°', 'ĠhÃ¼', 'entiful', 'SharedPtr']
#   Position 55 (Correct: 'Ġcylinder')    ['gow', "().'/", 'walls', 'wall', 'å°¼æĸ¯']
#   Position 56 (Correct: 'Ċ')            ['ystack', 'acements', '.apiUrl', 'emade', 'Ġ-----------------------------------------------------------------------------Ċ']
#   Position 57 (Correct: 'C')            ['quals', 'ISTRIBUT', 'lijah', 'stakes', 'bable']
#   Position 58 (Correct: '.')            ['æį¢åı¥è¯Ŀ', 'peater', 'Ġëĭ¤ë§Į', 'oins', '/lg']
#   Position 59 (Correct: 'ĠA')           ['Ð¸ÑĩÐµÑģ', 'antlr', 'ç©¹', 'getto', 'å¦ª']
#   Position 60 (Correct: 'Ġphoto')       ['ium', 'ioneer', 'asmus', 'urniture', '>>)']
#   Position 61 (Correct: 'Ġof')          ['scribe', 'voluciÃ³n', 'rive', 'ispens', 'udit']
#   Position 62 (Correct: 'Ġa')           ['Ø£ÙĪØ¶', 'ÑģÑĤÑĢÐ°Ð¸Ð²Ð°', 'ĠhÃ¼', 'entiful', 'SharedPtr']
#   Position 63 (Correct: 'Ġcone')        ['ILLISECONDS', 'ç®¡å§Ķä¼ļ', 'pcodes', 'Ð©', ')||(']
#   Position 64 (Correct: 'Ġleft')        ['Ġtaraf', 'åĿ¨', 'ahrain', 'Ġ}?>Ċ', 'ÙĪØµ']
#   Position 65 (Correct: 'Ġof')          ['scribe', 'voluciÃ³n', 'rive', 'ispens', 'udit']
#   Position 66 (Correct: 'Ġa')           ['Ø£ÙĪØ¶', 'ÑģÑĤÑĢÐ°Ð¸Ð²Ð°', 'ĠhÃ¼', 'entiful', 'SharedPtr']
#   Position 67 (Correct: 'Ġcylinder')    ['gow', "().'/", 'walls', 'wall', 'å°¼æĸ¯']
#   Position 68 (Correct: 'Ċ')            ['ystack', 'acements', '.apiUrl', 'emade', 'Ġ-----------------------------------------------------------------------------Ċ']
#   Position 69 (Correct: 'Answer')       ['æŀķ', 'æ²¡è§ģè¿ĩ', 'etrofit', 'å°±ç»Ļå¤§å®¶', 'å²ĳ']
#   Position 70 (Correct: 'Ġwith')        ['stood', 'äºĨåĩł', 'atonin', 'REATE', 'Ġiht']
#   Position 71 (Correct: 'Ġthe')         ['ÑģÑĤÑĢÐ°Ð¸Ð²Ð°', 'CLUDING', 'ðŁ¤ĵ', 'Ġtaraf', 'AVIS']
#   Position 72 (Correct: 'Ġletter')      ['picable', 'ruc', 'erializer', 'Ã¡cil', '<stdlib']
#   Position 73 (Correct: 'Ġof')          ['scribe', 'voluciÃ³n', 'rive', 'ispens', 'udit']
#   Position 74 (Correct: 'Ġthe')         ['ÑģÑĤÑĢÐ°Ð¸Ð²Ð°', 'CLUDING', 'ðŁ¤ĵ', 'Ġtaraf', 'AVIS']
#   Position 75 (Correct: 'Ġcorrect')     ['peater', 'Ġèĭ¥è¦ģ', 'ç¼¯', 'Ġ".$_', 'ainment']
#   Position 76 (Correct: 'Ġchoice')      ['Ġ}}"><', ".',čĊ", 'åĴĮä¸ªäºº', 'âļĹ', ']")]Ċ']
#   Position 77 (Correct: '.')            ['æį¢åı¥è¯Ŀ', 'peater', 'Ġëĭ¤ë§Į', 'oins', '/lg']
#   Position 78 (Correct: '[SPECIAL_151645]') ['oriously', '"],["', 'thal', '&);ĊĊ', 'ffb']
#   Position 79 (Correct: 'Ċ')            ['ystack', 'acements', '.apiUrl', 'emade', 'Ġ-----------------------------------------------------------------------------Ċ']
#   Position 80 (Correct: '[SPECIAL_151644]') ['ual', 'æł¼å¤ĸ', 'çĭ·', 'æĬ¥', 'findFirst']
#   Position 81 (Correct: 'assistant')    ['ĠNatÃ¼rlich', 'SearchTree', ')size', 'Ġ(![', ':on']
#   Position 82 (Correct: 'Ċ')            ['ystack', 'acements', '.apiUrl', 'emade', 'Ġ-----------------------------------------------------------------------------Ċ']
#
# Layer 1:
#   Position 0 (Correct: '[SPECIAL_151644]') ['åĹ«', 'ĠØ³Ø¨ØŃ', 'ãģķãģ¾ãģĸãģ¾', 'ä¸įåı¯æĢĿ', 'æ§ĺãĢħ']
#   Position 1 (Correct: 'system')       ['ÑĥÐ½Ð¸ÑĨÐ¸Ð¿', 'å¾Īå¤ļçİ©å®¶', 'ANDOM', 'ä¸įåħĭ', 'ä»İæł¹æľ¬']
#   Position 2 (Correct: 'Ċ')            ['IGGER', 'icester', 'ãĤĴè¶ħãģĪ', 'è®Ģåıĸ', 'ARSER']
#   Position 3 (Correct: 'You')          ['}ĊĊĊĊĊĊ', 'åķ¬', 'íĶĦë¡ľê·¸', 'ĠInherits', 'Êº']
#   Position 4 (Correct: 'Ġare')         ['èħ¼', 'åµ´', 'izoph', 'è¡Įäºĭ', 'ĠProductService']
#   Position 5 (Correct: 'Ġa')           ['åµ´', 'ĠRoose', 'Į¨', 'ify', 'variably']
#   Position 6 (Correct: 'Ġhelpful')     ['IGGER', 'oops', 'Į¨', 'çĳĢ', '----------------------------------------------------------------------Ċ']
ġáº¤', 'ĠØ³Ø¨ØŃ', 'ĠØªØ±Ø§Ùħ']
#   Position 63 (Correct: 'Ġcone')        ['Ġáº¤', 'ãģįãĤĮ', 'ĠØ§ÙĦÙĦØ¬', 'çķ¢ç«Ł', 'ãĥ¢ãĥĩ']
#   Position 64 (Correct: 'Ġleft')        ['ĠrÄĻk', 'ĠÙĬÙĪØ³', 'Ø¹Ø±ÙĪ', 'é«®', 'ØªØµØ±']
#   Position 65 (Correct: 'Ġof')          ['ä»İæł¹æľ¬', 'extracomment', 'ĠnovitÃł', 'ĠdifficoltÃł', 'CCI']
#   Position 66 (Correct: 'Ġa')           ['è®ĵä»ĸåĢĳ', 'ĠÙĬÙĪØ³', 'ĠØ³Ø¨ØŃ', 'ĠØªØ±Ø§Ùħ', 'Ġáº¤']
#   Position 67 (Correct: 'Ġcylinder')    ['Ġáº¤', 'ĠØ³Ø¨ØŃ', 'ĠØ§ÙĦÙĦØ¬', 'çķ¢ç«Ł', 'ĠØ§ÙĦØ«Ø§ÙĦ']
#   Position 68 (Correct: 'Ċ')            ['Ġáº¤', '/Dk', 'è®ĵä»ĸåĢĳ', 'ĠØ³Ø¨ØŃ', 'ĠØ§ÙĦØ¥Ø«ÙĨ']
#   Position 69 (Correct: 'Answer')       ['Ġáº¤', 'å¦Ĥæŀľçİ©å®¶', 'å»ļ', 'ãĤ·ãĥ§ãĥ¼', 'ĠØ³Ø¨ØŃ']
#   Position 70 (Correct: 'Ġwith')        ['ÙħØ¨Ø§Ø¯', 'ÙĨØªØ§Ø¦', 'Ø³Ø¤', 'ÙĨÙħÙĪØ°', 'åĻĺ']
#   Position 71 (Correct: 'Ġthe')         ['è®ĵä»ĸåĢĳ', 'ĠÙĬÙĪØ³', 'Ġáº¤', 'ĠØ§ÙĦÙĦØ¬', 'ĠØ³Ø¨ØŃ']
#   Position 72 (Correct: 'Ġletter')      ['ãģĬå¾Ĺ', 'ãĥľãĥ¼ãĥī', 'çķ¢ç«Ł', 'ç¿Ľ', 'ëª»']
#   Position 73 (Correct: 'Ġof')          ['Ġapproach', 'Ġembodiment', 'è¿Ļä¸ªèģĮä¸ļ', 'getSingleton', 'çĩĶ']
#   Position 74 (Correct: 'Ġthe')         ['è®ĵä»ĸåĢĳ', 'Ġáº¤', 'ĠÙĬÙĪØ³', 'ĠØ³Ø¨ØŃ', 'ĠØ§ÙĦÙĦØ¬']
#   Position 75 (Correct: 'Ġcorrect')     ['ìľĦìĽĲìŀ¥', 'Ø§ØŃØªÙħ', 'ØªØºÙĬ', 'ØªÙĪØ¬', '/Dk']
#   Position 76 (Correct: 'Ġchoice')      ['RYPTO', '^K', 'ØªÙĪØ¬', 'ĠMá»įi', 'Ø¨Ø±Ø´']
#   Position 77 (Correct: '.')            ['Ġáº¤', 'ãģĮå§ĭãģ¾', 'è®ĵä»ĸåĢĳ', 'ĠØ³Ø¨ØŃ', 'ĠØ§ÙĦØ«Ø§ÙĦ']
#   Position 78 (Correct: '[SPECIAL_151645]') ['è®ĵä»ĸåĢĳ', 'ĠØ³Ø¨ØŃ', 'ĠØ§ÙĦØ«Ø§ÙĦ', 'ĠÙĬÙĪØ³', 'ĠØ§ÙĦÙĦØ¬']
#   Position 79 (Correct: 'Ċ')            ['Ġáº¤', 'è®ĵä»ĸåĢĳ', '/Dk', 'ĠØ³Ø¨ØŃ', 'ç¾İéºĹ']
#   Position 80 (Correct: '[SPECIAL_151644]') ['Ġáº¤', 'ĠÙĬÙĪØ³', 'ĠØ§ÙĦÙĦØ¬', 'ĠØ³Ø¨ØŃ', 'è®ĵä»ĸåĢĳ']
#   Position 81 (Correct: 'assistant')    ['å¦Ĥæŀľçİ©å®¶', 'Ġáº¤', 'ãĤıãģĭãģ£ãģ¦', 'Ø£ÙģØ±', 'ãģįãĤĮ']
#   Position 82 (Correct: 'Ċ')            ['Ġáº¤', 'è®ĵä»ĸåĢĳ', 'ĠØ³Ø¨ØŃ', '/Dk', 'ĠØ§ÙĦØ£ÙĪØ±ÙĪ']
#
# Layer 2:
ĠØ³Ø¨ØŃ', 'ĠØ§ÙĦØ¹Ø±Ø§', 'Ġáº¤', 'ä¸įåı¯æĢĿ', 'ĠCÆ¡']
#   Position 19 (Correct: 'Task')         ['Ġáº¤', 'ä¸įåı¯æĢĿ', 'ĠÙĬÙĪØ³', 'é¾ĩ', 'áĲĪ']
#   Position 20 (Correct: ':')            ['Ġáº¤', 'ĠØ³Ø¨ØŃ', 'ĠØªØ±Ø§Ùħ', 'ĠØ§ÙĦØ¹Ø±Ø§', 'áĲĪ']
#   Position 21 (Correct: 'ĠIdentify')    ['ĠØªØ±Ø§Ùħ', 'ĠØ§ÙĦØ«Ø§ÙĦ', 'ä¸įåı¯æĢĿ', 'Ġáº¤', 'ĠÄĲiá»ĥm']
#   Position 22 (Correct: 'Ġthe')         ['Ġáº¤', 'ĠØ³Ø¨ØŃ', 'áĲĪ', 'ĠÙĬÙĪØ³', 'ĠØ§ÙĦÙĦØ¬']
#   Position 23 (Correct: 'Ġcorrect')     ['ĠÙĬÙĪØ³', 'ãĤĦãģ£ãģ±', 'ÙħÙĪØ§ÙĤÙģ', 'ĠØ³Ø¨ØŃ', 'ĠØªØ±Ø§Ùħ']
#   Position 24 (Correct: 'Ġlabel')       ['Ġáº¤', 'ĠØ³Ø¨ØŃ', 'ĠGiáº¥y', 'Ø§ÙĦØªØ²', 'ĠØªØ±Ø§Ùħ']
#   Position 25 (Correct: 'Ġfor')         ['ĠØ³Ø¨ØŃ', 'Ø´Ø¤', 'ĠnovitÃł', 'Ġáº¤', 'Ø£Ø®ÙĪ']
#   Position 26 (Correct: 'Ġthis')        ['Ġáº¤', 'è®ĵä»ĸåĢĳ', 'ĠØ§ÙĦØ¥Ø«ÙĨ', 'ĠØ§ÙĦØ«Ø§ÙĦ', 'ĠÙĬÙĪØ³']
#   Position 27 (Correct: 'Ġimage')       ['ĠØ§ÙĦØ«Ø§ÙĦ', 'ĠØ³Ø¨ØŃ', 'Ġáº¤', 'ĠÙĬÙĪØ³', 'ĠØ§ÙĦØ¹Ø±Ø§']
#   Position 28 (Correct: 'Ġfrom')        ['Ø´Ø¤', 'Ø£Ø®ÙĪ', 'Ø¨Ø±Ø´', 'Ġáº¤', 'ØªØºÙĬ']
#   Position 29 (Correct: 'Ġthe')         ['Ġáº¤', 'áĲĪ', 'ĠØ³Ø¨ØŃ', 'ĠÙĬÙĪØ³', 'ĠØ§ÙĦÙĦØ¬']
#   Position 30 (Correct: 'Ġfollowing')   ['ÑĤÐ²ÐµÑĢÐ¶Ð´Ð°', 'ç´łæķµ', 'ĠÙĬÙĪØ³', 'Ø§ÙĦØªØ²', 'ØªÙĨØ³ÙĬ']
#   Position 31 (Correct: 'Ġchoices')     ['Ø¨Ø±Ø´', 'ĠØ³Ø¨ØŃ', 'Ġáº¤', 'ĠØ§ÙĦØ«Ø§ÙĦ', 'ÙĨÙħÙĪØ°']
#   Position 32 (Correct: ':Ċ')           ['ĠØ³Ø¨ØŃ', 'ĠÙĬÙĪØ³', 'ĠØ§ÙĦØ¹Ø±Ø§', 'ãģĮå§ĭãģ¾', 'Ø´Ø¤']
#   Position 33 (Correct: 'A')            ['ĠÙĬÙĪØ³', 'ĠØ³Ø¨ØŃ', 'ĠØ§ÙĦÙĦØ¬', 'Ġáº¤', 'è®ĵä»ĸåĢĳ']
#   Position 34 (Correct: '.')            ['ĠØªØ±Ø§Ùħ', 'Ġáº¤', 'ĠØ³Ø¨ØŃ', 'ĠÙĬÙĪØ³', 'ĠØ§ÙĦÙĦØ¬']
#   Position 35 (Correct: 'ĠA')           ['ĠÙĬÙĪØ³', 'ĠØ§ÙĦÙĦØ¬', 'Ġáº¤', 'ĠØ³Ø¨ØŃ', 'è®ĵä»ĸåĢĳ']
#   Position 36 (Correct: 'Ġphoto')       ['ĠØ³Ø¨ØŃ', 'ĠÙĬÙĪØ³', 'Ø§ÙĦØªØ²', 'Ø£ØºÙĦØ¨', 'Ġáº¤']
#   Position 37 (Correct: 'Ġof')          ['ĠØ³Ø¨ØŃ', 'ĠØ§ÙĦØ«Ø§ÙĦ', 'ĠÙĬÙĪØ³', 'ÙħÙĪØ§ÙĤÙģ', 'ãģªãģıãģªãģ£ãģ¦']
#   Position 38 (Correct: 'Ġa')           ['è®ĵä»ĸåĢĳ', 'Ġáº¤', 'ĠÙĬÙĪØ³', 'ĠØ³Ø¨ØŃ', 'áĲĪ']
#   Position 39 (Correct: 'Ġcylinder')    ['Ġáº¤', 'ĠØ³Ø¨ØŃ', 'ĠØ§ÙĦÙĦØ�
ġáº¤', 'ĠÙĬÙĪØ³', 'ĠØ§ÙĦÙĦØ¬', 'ĠØ³Ø¨ØŃ', 'ÙħÙĪØ§ÙĤÙģ']
#   Position 36 (Correct: 'Ġphoto')       ['ĠØ³Ø¨ØŃ', 'ĠÙĬÙĪØ³', 'Ø§ÙĦØªØ²', 'Ġáº¤', 'Ø£ØºÙĦØ¨']
#   Position 37 (Correct: 'Ġof')          ['ĠØ³Ø¨ØŃ', 'ĠÙĬÙĪØ³', 'ĠØ§ÙĦØ«Ø§ÙĦ', 'Ġáº¤', 'ÙħÙĪØ§ÙĤÙģ']
#   Position 38 (Correct: 'Ġa')           ['Ġáº¤', 'ĠØ³Ø¨ØŃ', 'ĠÙĬÙĪØ³', 'è®ĵä»ĸåĢĳ', 'áĲĪ']
#   Position 39 (Correct: 'Ġcylinder')    ['Ġáº¤', 'áĲĪ', 'ĠÙĬÙĪØ³', 'ĠØ³Ø¨ØŃ', 'Ø£ÙģØ±']
#   Position 40 (Correct: 'Ġright')       ['é¾ĩ', 'æĮģãģ£ãģ¦ãģĦ', 'ĠØ§ÙĦØ¥Ø«ÙĨ', 'ãģĦãģ£ãģ±', 'ÙħÙĪØ§ÙĤÙģ']
#   Position 41 (Correct: 'Ġof')          ['ĠØ§ÙĦØ¥Ø«ÙĨ', 'ĠØ§ÙĦØ«Ø§ÙĦ', 'ÙĨÙħÙĪØ°', 'ãģĦãģ£ãģ±', 'ĠØ§ÙĦØ¯ÙĨÙĬ']
#   Position 42 (Correct: 'Ġa')           ['ĠØ³Ø¨ØŃ', 'ĠÙĬÙĪØ³', 'è®ĵä»ĸåĢĳ', 'Ġáº¤', 'ĠØ§ÙĦÙĦØ¬']
#   Position 43 (Correct: 'Ġcone')        ['Ġáº¤', 'ÙħÙĪØ§ÙĤÙģ', 'Ø£ÙģØ±', 'ĠØ³Ø¨ØŃ', 'ĠØ£ÙģØ±ÙĬ']
#   Position 44 (Correct: 'Ċ')            ['Ġáº¤', 'ĠØ³Ø¨ØŃ', 'ĠØ§ÙĦØ«Ø§ÙĦ', 'ĠØ§ÙĦØ¹Ø±Ø§', 'ĠØ§ÙĦØ¥Ø«ÙĨ']
#   Position 45 (Correct: 'B')            ['åĹ«', 'è®ĵä»ĸåĢĳ', 'ĠDiá»ħn', 'ÙħÙĪØ§ÙĤÙģ', 'ĠÙĬÙĪÙĦ']
#   Position 46 (Correct: '.')            ['Ġáº¤', 'ĠØ³Ø¨ØŃ', 'è®ĵä»ĸåĢĳ', 'ĠÙĬÙĪØ³', 'áĲĪ']
#   Position 47 (Correct: 'ĠA')           ['ĠØ§ÙĦÙĦØ¬', 'ĠØ³Ø¨ØŃ', 'ĠÙĬÙĪØ³', 'Ġáº¤', 'áĲĪ']
#   Position 48 (Correct: 'Ġphoto')       ['ĠØ³Ø¨ØŃ', 'ĠÙĬÙĪØ³', 'Ġáº¤', 'ĠØ§ÙĦØ«Ø§ÙĦ', 'Ø£ØºÙĦØ¨']
#   Position 49 (Correct: 'Ġof')          ['ĠÙĬÙĪØ³', 'ĠØ³Ø¨ØŃ', 'ĠØ§ÙĦØ«Ø§ÙĦ', 'Ġáº¤', 'ĠØ§ÙĦØ¥Ø«ÙĨ']
#   Position 50 (Correct: 'Ġa')           ['Ġáº¤', 'ĠØ³Ø¨ØŃ', 'ĠÙĬÙĪØ³', 'è®ĵä»ĸåĢĳ', 'áĲĪ']
#   Position 51 (Correct: 'Ġcone')        ['Ġáº¤', 'ĠØ³Ø¨ØŃ', 'ÙħÙĪØ§ÙĤÙģ', 'ĠØ§ÙĦÙĦØ¬', 'Ø£ÙģØ±']
#   Position 52 (Correct: 'Ġright')       ['é¾ĩ', 'æĮģãģ£ãģ¦ãģĦ', 'è®ĵä»ĸåĢĳ', 'ĠØ§ÙĦØ¥Ø«ÙĨ', 'ãģĦãģ£ãģ±']
#   Position 53 (Correct: 'Ġof')          ['ãĥ¢ãĥĩ', 'ĠØ§ÙĦØ¥Ø«ÙĨ', 'ĠØ§ÙĦØ«Ø§ÙĦ', 'ãĤ¦ãĤ©ãĥ¼', 'ãģĦãģ£ãģ±']
#   Position 54 (Correct: 'Ġa')           ['ĠØ³Ø¨ØŃ', 'è®ĵä»ĸåĢĳ', 'ĠÙĬÙĪØ³', 'Ġáº¤', 'áĲĪ']
#   Position 55 (Correct: 'Ġcylinder')    ['Ġáº¤', 'áĲĪ', 'Ø£ÙģØ±', 'ĠÙĬÙĪØ³', 'ÙĨÙħÙĪØ°']
#   Position 56 (Correct: 'Ċ')            ['Ġáº¤', 'ĠØ§ÙĦØ¥Ø«ÙĨ', 'ĠØ³Ø¨ØŃ', 'ĠØ§ÙĦØ«Ø§ÙĦ', '�
#   Position 74 (Correct: 'Ġthe')         ['Ġáº¤', 'ĠØ³Ø¨ØŃ', 'è®ĵä»ĸåĢĳ', 'ĠÙĬÙĪØ³', 'áĲĪ']
#   Position 75 (Correct: 'Ġcorrect')     ['ØªÙĪØ¬', 'ĠØªØ±Ø§Ùħ', '$MESS', 'ØªØºÙĬ', 'ĠÙĬÙĪØ³']
#   Position 76 (Correct: 'Ġchoice')      ['ĠØ§ÙĦÙĦØ¬', 'Ġáº¤', 'ĠØ³Ø¨ØŃ', 'ĠØ§ÙĦØ«Ø§ÙĦ', 'ÙĨÙħÙĪØ°']
#   Position 77 (Correct: '.')            ['Ġáº¤', 'áĲĪ', 'ĠØ³Ø¨ØŃ', 'Ø´Ø¤', 'ĠÙĬÙĪØ³']
#   Position 78 (Correct: '[SPECIAL_151645]') ['ĠØ³Ø¨ØŃ', 'åĹ«', 'ä»İæł¹æľ¬', 'ĠØ§ÙĦÙĦØ¬', 'ĠØ§ÙĦØ«Ø§ÙĦ']
#   Position 79 (Correct: 'Ċ')            ['ĠØ³Ø¨ØŃ', 'Ġáº¤', 'ĠÙĬÙĪØ³', 'ĠØ§ÙĦØ¥Ø«ÙĨ', 'ĠØ§ÙĦØ¹Ø±Ø§']
#   Position 80 (Correct: '[SPECIAL_151644]') ['ĠØ³Ø¨ØŃ', 'Ġáº¤', 'ĠØ§ÙĦÙĦØ¬', 'ä»İæł¹æľ¬', 'è®ĵä»ĸåĢĳ']
#   Position 81 (Correct: 'assistant')    ['Ø¥Ø²', 'å¦Ĥæŀľçİ©å®¶', 'Ø¥ØµØ¯Ø§Ø±', 'Ø£ÙģØ±', 'Ø§Ø®ÙĦ']
#   Position 82 (Correct: 'Ċ')            ['ĠØ³Ø¨ØŃ', 'Ġáº¤', 'áĲĪ', 'ĠÙĬÙĪØ³', 'ĠØ§ÙĦÙĦØ¬']
#
# Layer 4:
#   Position 0 (Correct: '[SPECIAL_151644]') ['ĠØ§ÙĦØ¹Ø±Ø§', 'ĠØ³Ø¨ØŃ', 'Ġáº¤', 'åĹ«', 'ãģįãĤĮ']
#   Position 1 (Correct: 'system')       ['ØªÙĤØ§Ø±', 'å¾Īå¤ļçİ©å®¶', 'ãĥľãĥ¼ãĥī', 'ĠØ§ÙĦØ¹Ø±Ø§', 'æĮģãģ£ãģ¦ãģĦ']
#   Position 2 (Correct: 'Ċ')            ['áĲĪ', 'Ġáº¤', 'áĲī', 'ØªØ¬Ø§', 'Ø£ÙģØ±']
#   Position 3 (Correct: 'You')          ['ãģįãĤĮ', 'ØªØ¸', 'è»Łé«Ķ', 'çķ¢ç«Ł', 'ê¹Ķ']
#   Position 4 (Correct: 'Ġare')         ['ØªÙĨØ³ÙĬ', 'Ø§ÙĦØªØ²', 'èħ¼', 'è®ĵä»ĸåĢĳ', 'ÙħÙĪØ§ÙĤÙģ']
#   Position 5 (Correct: 'Ġa')           ['æĤ»', '_STRUCTURE', 'èħ¼', 'è®ĵä»ĸåĢĳ', 'ĠGeschÃ¤']
#   Position 6 (Correct: 'Ġhelpful')     ['ØªØ¬Ø§', 'Ġáº¤', 'Ø£ÙģØ±', 'Ø£ØºÙĦØ¨', 'Ø£Ø®ÙĪ']
#   Position 7 (Correct: 'Ġassistant')   ['Ġáº¤', 'åķĲ', 'åĻĺ', 'ĠTruyá»ģn', '/Dk']
', 'Ġáº¤', 'ĠÙĬÙĪØ³', 'å¾Īå¤ļçİ©å®¶', 'ĠØ§ÙĦØ«Ø§ÙĦ']
#   Position 27 (Correct: 'Ġimage')       ['ĠØ³Ø¨ØŃ', 'ĠØ§ÙĦØ«Ø§ÙĦ', 'Ġáº¤', 'ĠÙĬÙĪØ³', 'ĠØ§ÙĦØ¥Ø«ÙĨ']
#   Position 28 (Correct: 'Ġfrom')        ['Ġáº¤', 'Ø´Ø¤', 'ØªØ¸', 'Ø¥Ø²', 'ÙĨÙħÙĪØ°']
#   Position 29 (Correct: 'Ġthe')         ['è®ĵä»ĸåĢĳ', 'Ġáº¤', 'áĲĪ', 'ĠØ§ÙĦÙĦØ¬', 'ĠÙĬÙĪØ³']
#   Position 30 (Correct: 'Ġfollowing')   ['ÑĤÐ²ÐµÑĢÐ¶Ð´Ð°', 'Ø§ØŃØªÙħ', '$MESS', 'ãģĬå¾Ĺ', 'ãĥľãĥ¼ãĥī']
#   Position 31 (Correct: 'Ġchoices')     ['ĠØ§ÙĦØ«Ø§ÙĦ', 'ĠØ§ÙĦÙĦØ¬', 'ĠØªØ±Ø§Ùħ', 'ĠØ³Ø¨ØŃ', 'ÙĨÙħÙĪØ°']
#   Position 32 (Correct: ':Ċ')           ['ĠØ³Ø¨ØŃ', 'ĠØ§ÙĦØ¹Ø±Ø§', 'Ø´Ø¤', 'ĠÙĬÙĪØ³', 'ãģĮå§ĭãģ¾']
#   Position 33 (Correct: 'A')            ['ĠØ³Ø¨ØŃ', 'ĠÙĬÙĪØ³', 'ĠØ§ÙĦÙĦØ¬', 'ĠØ§ÙĦØ«Ø§ÙĦ', 'áĲĪ']
#   Position 34 (Correct: '.')            ['ĠÙĬÙĪØ³', 'ĠØªØ±Ø§Ùħ', 'ĠDiá»ħn', 'Ġáº¤', 'ĠØ³Ø¨ØŃ']
#   Position 35 (Correct: 'ĠA')           ['ĠØ§ÙĦÙĦØ¬', 'ĠÙĬÙĪØ³', 'Ġáº¤', 'ØªÙĦÙģØ²ÙĬÙĪÙĨ', 'ãģ¦ãģĹãģ¾ãģ£ãģ¦']
#   Position 36 (Correct: 'Ġphoto')       ['ĠØ³Ø¨ØŃ', 'ĠÙĬÙĪØ³', 'Ø§ÙĦØªØ²', 'ĠØ§ÙĦØ«Ø§ÙĦ', 'Ġáº¤']
#   Position 37 (Correct: 'Ġof')          ['ĠÙĬÙĪØ³', 'ĠØ³Ø¨ØŃ', 'ĠØ§ÙĦØ«Ø§ÙĦ', 'Ġáº¤', 'ÙħÙĪØ§ÙĤÙģ']
#   Position 38 (Correct: 'Ġa')           ['Ġáº¤', 'ĠØ³Ø¨ØŃ', 'è®ĵä»ĸåĢĳ', 'ĠÙĬÙĪØ³', 'ĠØ§ÙĦÙĦØ¬']
#   Position 39 (Correct: 'Ġcylinder')    ['Ġáº¤', 'áĲĪ', 'áĲī', 'ĠØ³Ø¨ØŃ', 'Ø£ÙģØ±']
#   Position 40 (Correct: 'Ġright')       ['é¾ĩ', 'ĠØ§ÙĦØ¥Ø«ÙĨ', 'ÙĨÙħÙĪØ°', 'æĮģãģ£ãģ¦ãģĦ', 'ãģĦãģ£ãģ±']
#   Position 41 (Correct: 'Ġof')          ['ÙĨÙħÙĪØ°', 'ĠØ§ÙĦØ¥Ø«ÙĨ', 'Ø´Ø¤', 'è®ĵä»ĸåĢĳ', 'ãģĦãģ£ãģ±']
#   Position 42 (Correct: 'Ġa')           ['ĠØ³Ø¨ØŃ', 'è®ĵä»ĸåĢĳ', 'ĠÙĬÙĪØ³', 'ĠØ§ÙĦÙĦØ¬', 'áĲĪ']
#   Position 43 (Correct: 'Ġcone')        ['ÙħÙĪØ§ÙĤÙģ', 'Ġáº¤', 'ĠØªØ±Ø§Ùħ', 'ĠØ§ÙĦÙĦØ¬', 'ĠØ³Ø¨ØŃ']
#   Position 44 (Correct: 'Ċ')            ['Ġáº¤', 'ĠØ³Ø¨ØŃ', 'ĠØ§ÙĦØ«Ø§ÙĦ', '�
 'ĠØ³Ø¨ØŃ', 'ĠÙĬÙĪØ³']
#
# Layer 5:
#   Position 0 (Correct: '[SPECIAL_151644]') ['ĠØ§ÙĦØ¹Ø±Ø§', 'ĠØ³Ø¨ØŃ', 'Ġáº¤', 'áĲĪ', 'ÙħÙĪØ§ÙĤÙģ']
#   Position 1 (Correct: 'system')       ['ØªÙĤØ§Ø±', 'ãĥľãĥ¼ãĥī', 'ØªØ¸Ø§ÙĩØ±', 'ĠØ§ÙĦØ¹Ø±Ø§', 'ãĤĦãģ£ãģ±']
#   Position 2 (Correct: 'Ċ')            ['áĲĪ', 'Ġáº¤', 'ØªØ¬Ø§', 'áĲī', 'Ø£ÙģØ±']
#   Position 3 (Correct: 'You')          ['ãģįãĤĮ', 'ØªØ¸', 'çķ¢ç«Ł', 'ãĥ¢ãĥĩ', 'è»Łé«Ķ']
#   Position 4 (Correct: 'Ġare')         ['ØªÙĨØ³ÙĬ', 'Ø§ÙĦØªØ²', 'è®ĵä»ĸåĢĳ', 'ØªØºÙĬ', 'ãģįãĤĮ']
#   Position 5 (Correct: 'Ġa')           ['ØªØ¬Ø§', 'æĤ»', 'è®ĵä»ĸåĢĳ', 'èħ¼', 'ĠGeschÃ¤']
#   Position 6 (Correct: 'Ġhelpful')     ['ØªØ¬Ø§', 'Ġáº¤', 'Ø£ÙģØ±', 'Ø£Ø®ÙĪ', 'Ø£ØºÙĦØ¨']
#   Position 7 (Correct: 'Ġassistant')   ['Ġáº¤', 'ĠTruyá»ģn', 'åķĲ', 'ĠDiá»ħn', 'æĮģãģ£ãģ¦ãģĦ']
#   Position 8 (Correct: '.')            ['é¾ĩ', 'æĮģãģ£ãģ¦ãģĦ', 'ä»İæł¹æľ¬', 'ØªØ¬Ø§', 'èħ¼']
#   Position 9 (Correct: '[SPECIAL_151645]') ['æĤ»', 'æĸ°åŀĭåĨł', 'é¾ĩ', 'ãĥľãĥ¼', 'ä»İæł¹æľ¬']
#   Position 10 (Correct: 'Ċ')            ['ãĥľãĥ¼ãĥī', 'ãģįãĤĮ', 'ãĤĦãģ£ãģ±', 'Ø£ØºÙĦØ¨', 'ĠØ§ÙĦØ¹Ø±Ø§']
#   Position 11 (Correct: '[SPECIAL_151644]') ['ØªØ¬Ø§', 'ãĥ¢ãĥĩ', 'é¾ĩ', 'æĮģãģ£ãģ¦ãģĦ', 'áĲĪ']
#   Position 12 (Correct: 'user')         ['ĠØ§ÙĦØ¥Ø«ÙĨ', 'ĠÙĬÙĪØ³', 'ãĤ¦ãĤ©ãĥ¼', 'ĠØ§ÙĦØ£ÙĪØ±ÙĪ', 'ĠØ§ÙĦØ¹Ø±Ø§']
#   Position 13 (Correct: 'Ċ')            ['ĠØ³Ø¨ØŃ', 'ĠØ§ÙĦØ¹Ø±Ø§', 'áĲĪ', 'ĠÙĬÙĪØ³', '/Dk']
#   Position 14 (Correct: '[SPECIAL_-301]') ['/Dk', 'ĠØ³Ø¨ØŃ', 'ĠÙĬÙĪØ³', 'ĠØªØ±Ø§Ùħ', 'çİĵ']
#   Position 15 (Correct: '[SPECIAL_-300]') ['Ø¥Ø²', 'æį¢åı¥è¯Ŀ', 'ĠDiá»ħn', 'é¢¨æł¼', 'èĨ½']
#   Position 16 (Correct: '[SPECIAL_-302]') ['armac', '±', 'estruction', 'azu', 'ccoli']
#   Position 17 (Correct: '[SPECIAL_-305]') ['abyrin', 'ëŀ¬', 'traÃ®n', 'åªŀ', '.moves']
ĠØ³Ø¨ØŃ', 'ĠÙĬÙĪØ³', 'Ø§ÙĦØªØ²', 'ĠØ§ÙĦÙħØ±Ø£', 'Ø£ØºÙĦØ¨']
#   Position 37 (Correct: 'Ġof')          ['ĠÙĬÙĪØ³', 'ĠØ³Ø¨ØŃ', 'ĠØ§ÙĦØ«Ø§ÙĦ', 'Ġáº¤', 'ÙħÙĪØ§ÙĤÙģ']
#   Position 38 (Correct: 'Ġa')           ['ĠÙĬÙĪØ³', 'ĠØ³Ø¨ØŃ', 'ĠØ§ÙĦÙĦØ¬', 'áĲĪ', 'Ġáº¤']
#   Position 39 (Correct: 'Ġcylinder')    ['áĲĪ', 'Ġáº¤', 'áĲī', 'ĠØ³Ø¨ØŃ', 'ĠÙĬÙĪØ³']
#   Position 40 (Correct: 'Ġright')       ['é¾ĩ', 'æĮģãģ£ãģ¦ãģĦ', 'ĠØ§ÙĦØ¥Ø«ÙĨ', 'ãģĦãģ£ãģ±', 'âļĹ']
#   Position 41 (Correct: 'Ġof')          ['Ø´Ø¤', 'ãģĦãģ£ãģ±', 'ãĥ¢ãĥĩ', 'ĠØ§ÙĦØ¹Ø±Ø§', 'ãĤ·ãĥ§ãĥ¼']
#   Position 42 (Correct: 'Ġa')           ['áĲĪ', 'ĠØ§ÙĦÙĦØ¬', 'ĠØ³Ø¨ØŃ', 'Ø´Ø¤', 'è®ĵä»ĸåĢĳ']
#   Position 43 (Correct: 'Ġcone')        ['ÙħÙĪØ§ÙĤÙģ', 'ĠØ§ÙĦÙĦØ¬', 'Ġáº¤', 'ĠØªØ±Ø§Ùħ', 'áĲĪ']
#   Position 44 (Correct: 'Ċ')            ['ĠØ³Ø¨ØŃ', 'ĠØ§ÙĦØ«Ø§ÙĦ', 'ĠØ§ÙĦØ¹Ø±Ø§', 'ĠØ§ÙĦØ¥Ø«ÙĨ', 'Ġáº¤']
#   Position 45 (Correct: 'B')            ['ĠØ§ÙĦØ¥Ø«ÙĨ', 'ĠDiá»ħn', 'è®ĵä»ĸåĢĳ', 'ĠØ§ÙĦØ«Ø§ÙĦ', '/Dk']
#   Position 46 (Correct: '.')            ['áĲĪ', 'ĠÙĬÙĪØ³', 'ĠØ³Ø¨ØŃ', 'Ġáº¤', 'ĠØ§ÙĦØ¥Ø«ÙĨ']
#   Position 47 (Correct: 'ĠA')           ['ĠØ§ÙĦÙĦØ¬', 'ĠÙĬÙĪØ³', 'Ġáº¤', 'áĲĪ', 'ĠØ³Ø¨ØŃ']
#   Position 48 (Correct: 'Ġphoto')       ['ĠØ³Ø¨ØŃ', 'ĠÙĬÙĪØ³', 'Ġáº¤', 'ĠØ§ÙĦØ«Ø§ÙĦ', 'ĠØ§ÙĦØ¥Ø«ÙĨ']
#   Position 49 (Correct: 'Ġof')          ['ĠÙĬÙĪØ³', 'ĠØ³Ø¨ØŃ', 'áĲĪ', 'ĠØ§ÙĦØ«Ø§ÙĦ', 'Ġáº¤']
#   Position 50 (Correct: 'Ġa')           ['ĠÙĬÙĪØ³', 'áĲĪ', 'Ġáº¤', 'è®ĵä»ĸåĢĳ', 'ĠØ³Ø¨ØŃ']
#   Position 51 (Correct: 'Ġcone')        ['Ġáº¤', 'ĠØ§ÙĦÙĦØ¬', 'ĠØ³Ø¨ØŃ', 'ÙħÙĪØ§ÙĤÙģ', 'áĲĪ']
#   Position 52 (Correct: 'Ġright')       ['é¾ĩ', 'ĠØ§ÙĦØ¥Ø«ÙĨ', 'ãģĦãģ£ãģ±', 'æĮģãģ£ãģ¦ãģĦ', 'è®ĵä»ĸåĢĳ']
#   Position 53 (Correct: 'Ġof')          ['Ø´Ø¤', 'ãĥ¢ãĥĩ', 'ĠØ§ÙĦØ¥Ø«ÙĨ', 'ãģĦãģ£ãģ±', 'ãĥľãĥ¼ãĥī']
#   Position 54 (Correct: 'Ġa')           ['è®ĵä»ĸåĢĳ', 'áĲĪ', 'ĠØ§ÙĦØ¥Ø«ÙĨ', 'Ø´Ø¤', 'ĠÙĬÙĪØ³']
#   Position 55 (Correct: 'Ġcylinder')    ['áĲĪ', 'áĲī', 'Ġáº¤', 'Ø£ÙģØ±', 'Ø¥Ø²']
#   Position 56 (Correct: 'Ċ')            ['ĠØ§ÙĦØ¥Ø«ÙĨ', 'Ġáº¤', 'ĠØ³Ø¨ØŃ', 'ĠØ§ÙĦØ«Ø§ÙĦ', '
 'ĠØ³Ø¨ØŃ', 'ĠØ§ÙĦØ£ÙĪØ±ÙĪ']
#   Position 75 (Correct: 'Ġcorrect')     ['ĠØªØ±Ø§Ùħ', 'ĠÙĬÙĪØ³', 'ĠØ§ÙĦÙĦØ¬', 'ĠØ§ÙĦØ®Ùħ', 'ĠØ³Ø¨ØŃ']
#   Position 76 (Correct: 'Ġchoice')      ['ĠØ³Ø¨ØŃ', 'ĠØ§ÙĦÙĦØ¬', 'traÃ®n', 'ĠØ§ÙĦØ«Ø§ÙĦ', 'ĠØ£ÙģØ±ÙĬ']
#   Position 77 (Correct: '.')            ['ĠØ³Ø¨ØŃ', 'Ġáº¤', 'ĠØ§ÙĦØ¥Ø«ÙĨ', 'áĲĪ', 'ĠØ§ÙĦØ¹Ø±Ø§']
#   Position 78 (Correct: '[SPECIAL_151645]') ['Ġáº¤', 'ĠØ³Ø¨ØŃ', 'ĠØ§ÙĦØ¥Ø«ÙĨ', 'áĲĪ', 'ĠØ§ÙĦÙĦØ¬']
#   Position 79 (Correct: 'Ċ')            ['ĠØ³Ø¨ØŃ', 'ĠØ§ÙĦØ£ÙĪØ±ÙĪ', 'ĠØ§ÙĦØ¥Ø«ÙĨ', 'ĠØ§ÙĦØ¹Ø±Ø§', 'Ġáº¤']
#   Position 80 (Correct: '[SPECIAL_151644]') ['Ġáº¤', 'ĠØ³Ø¨ØŃ', 'áĲĪ', 'ĠØ§ÙĦØ¥Ø«ÙĨ', 'ĠØ§ÙĦÙĦØ¬']
# ...
#   Position 66 (Correct: 'Ġa')           ['áĲĪ', 'Ġáº¤', 'ĠÙĬÙĪØ³', 'áĲī', 'ĠØ³Ø¨ØŃ']
#   Position 67 (Correct: 'Ġcylinder')    ['áĲĪ', 'Ġáº¤', 'áĲī', 'Ø´Ø¤', 'ĠØ³Ø¨ØŃ']
#   Position 68 (Correct: 'Ċ')            ['áĲĪ', 'ĠØ³Ø¨ØŃ', 'áĲī', 'ĠÙĬÙĪØ³', 'ĠØ§ÙĦØ¹Ø±Ø§']
#   Position 69 (Correct: 'Answer')       ['áĲĪ', 'Ġáº¤', 'ĠÙĬÙĪØ³', 'áĲī', 'ĠØ³Ø¨ØŃ']
#   Position 70 (Correct: 'Ġwith')        ['áĲĪ', 'Ġáº¤', 'ĠÙĬÙĪØ³', 'ĠØ³Ø¨ØŃ', 'ĠØ§ÙĦØ¹Ø±Ø§']
#   Position 71 (Correct: 'Ġthe')         ['ĠÙĬÙĪØ³', 'Ġáº¤', 'áĲĪ', 'ĠØ³Ø¨ØŃ', 'ĠØ§ÙĦÙĦØ¬']
#   Position 72 (Correct: 'Ġletter')      ['ĠÙĬÙĪØ³', 'ĠØ³Ø¨ØŃ', 'Ġáº¤', 'áĲĪ', 'ĠØ§ÙĦÙĦØ¬']
#   Position 73 (Correct: 'Ġof')          ['ĠÙĬÙĪØ³', 'ĠØ³Ø¨ØŃ', 'Ġáº¤', 'áĲĪ', 'ĠØ§ÙĦÙĦØ¬']
#   Position 74 (Correct: 'Ġthe')         ['áĲĪ', 'Ġáº¤', 'ĠØ³Ø¨ØŃ', 'ĠÙĬÙĪØ³', 'ĠØ§ÙĦÙĦØ¬']
#   Position 75 (Correct: 'Ġcorrect')     ['Ġáº¤', 'áĲĪ', 'ĠØ³Ø¨ØŃ', 'ĠÙĬÙĪØ³', 'ĠØ§ÙĦÙĦØ¬']
#   Position 76 (Correct: 'Ġchoice')      ['áĲĪ', 'ĠØ³Ø¨ØŃ', 'ĠÙĬÙĪØ³', 'Ġáº¤', 'ĠØ§ÙĦÙĦØ¬']
#   Position 77 (Correct: '.')            ['áĲĪ', 'áĲī', 'Ġáº¤', 'ĠÙĬÙĪØ³', 'ĠØ§ÙĦÙĦØ¬']
#   Position 78 (Correct: '[SPECIAL_151645]') ['áĲĪ', 'Ġáº¤', 'áĲī', 'ĠØ³Ø¨ØŃ', 'ĠÙĬÙĪØ³']
#   Position 79 (Correct: 'Ċ')            ['áĲĪ', 'Ġáº¤', 'ĠØ³Ø¨ØŃ', 'ĠÙĬÙĪØ³', 'áĲī']
#   Position 80 (Correct: '[SPECIAL_151644]') ['áĲĪ', 'Ġáº¤', 'ĠÙĬÙĪØ³', 'ĠØ³Ø¨ØŃ', 'ĠØ§ÙĦÙĦØ¬']
#   Position 81 (Correct: 'assistant')    ['áĲĪ', 'Ġáº¤', 'áĲī', 'ĠØ§ÙĦØ£ÙĪØ±ÙĪ', 'ĠØ§ÙĦÙĦØ¬']
#   Position 82 (Correct: 'Ċ')            ['áĲĪ', 'Ġáº¤', 'áĲī', 'ĠÙĬÙĪØ³', 'ĠØ³Ø¨ØŃ']
#
# Layer 27:
#   Position 0 (Correct: '[SPECIAL_151644]') ['Ġáº¤', 'áĲĪ', 'áĲī', 'ĠØ§ÙĦÙĦØ¬', 'ĠØ³Ø¨ØŃ']
#   Position 1 (Correct: 'system')       ['áĲĪ', 'Ġáº¤', 'ĠØ§ÙĦØ¹Ø±Ø§', 'ĠÙĬÙĪØ³', 'ĠØ³Ø¨ØŃ']
#   Position 2 (Correct: 'Ċ')            ['áĲĪ', 'Ġáº¤', 'ĠÙĬÙĪØ³', 'ĠØ³Ø¨ØŃ', 'Ø´Ø¤']
#   Position 3 (Correct: 'You')          ['áĲĪ', 'Ġáº¤', 'ĠÙĬÙĪØ³', 
ġáº¤', 'ĠØ³Ø¨ØŃ', 'ĠÙĬÙĪØ³', 'áĲī']
#   Position 64 (Correct: 'Ġleft')        ['áĲĪ', 'Ġáº¤', 'ĠÙĬÙĪØ³', 'Ø´Ø¤', 'áĲī']
#   Position 65 (Correct: 'Ġof')          ['áĲĪ', 'Ġáº¤', 'Ø´Ø¤', 'ĠÙĬÙĪØ³', 'áĲī']
#   Position 66 (Correct: 'Ġa')           ['áĲĪ', 'Ġáº¤', 'ĠÙĬÙĪØ³', 'áĲī', 'Ø´Ø¤']
#   Position 67 (Correct: 'Ġcylinder')    ['áĲĪ', 'Ġáº¤', 'ĠØ³Ø¨ØŃ', 'ĠÙĬÙĪØ³', 'Ø´Ø¤']
#   Position 68 (Correct: 'Ċ')            ['áĲĪ', 'ĠØ³Ø¨ØŃ', 'Ġáº¤', 'áĲī', 'ĠØ§ÙĦÙĦØ¬']
#   Position 69 (Correct: 'Answer')       ['áĲĪ', 'Ġáº¤', 'ĠÙĬÙĪØ³', 'áĲī', 'ĠØ³Ø¨ØŃ']
#   Position 70 (Correct: 'Ġwith')        ['áĲĪ', 'Ġáº¤', 'ĠÙĬÙĪØ³', 'ĠØ³Ø¨ØŃ', 'ĠØ§ÙĦÙĦØ¬']
#   Position 71 (Correct: 'Ġthe')         ['Ġáº¤', 'ĠÙĬÙĪØ³', 'áĲĪ', 'ĠØ³Ø¨ØŃ', 'ĠØ§ÙĦÙĦØ¬']
#   Position 72 (Correct: 'Ġletter')      ['ĠÙĬÙĪØ³', 'Ġáº¤', 'ĠØ³Ø¨ØŃ', 'áĲĪ', 'ĠØ§ÙĦÙĦØ¬']
#   Position 73 (Correct: 'Ġof')          ['ĠÙĬÙĪØ³', 'ĠØ³Ø¨ØŃ', 'Ġáº¤', 'áĲĪ', 'ĠØ§ÙĦÙĦØ¬']
#   Position 74 (Correct: 'Ġthe')         ['áĲĪ', 'Ġáº¤', 'ĠÙĬÙĪØ³', 'ĠØ³Ø¨ØŃ', 'ĠØ§ÙĦÙĦØ¬']
#   Position 75 (Correct: 'Ġcorrect')     ['Ġáº¤', 'ĠÙĬÙĪØ³', 'áĲĪ', 'ĠØ³Ø¨ØŃ', 'ĠØ§ÙĦÙĦØ¬']
#   Position 76 (Correct: 'Ġchoice')      ['áĲĪ', 'ĠÙĬÙĪØ³', 'Ġáº¤', 'ĠØ³Ø¨ØŃ', 'ĠØ§ÙĦÙĦØ¬']
#   Position 77 (Correct: '.')            ['áĲĪ', 'Ġáº¤', 'áĲī', 'ĠÙĬÙĪØ³', 'ĠØ§ÙĦØ¥Ø«ÙĨ']
#   Position 78 (Correct: '[SPECIAL_151645]') ['áĲĪ', 'Ġáº¤', 'áĲī', 'ĠØ§ÙĦÙĦØ¬', 'ĠØ§ÙĦØ¥Ø«ÙĨ']
#   Position 79 (Correct: 'Ċ')            ['áĲĪ', 'Ġáº¤', 'ĠÙĬÙĪØ³', 'ĠØ³Ø¨ØŃ', 'ĠØ§ÙĦÙĦØ¬']
#   Position 80 (Correct: '[SPECIAL_151644]') ['Ġáº¤', 'áĲĪ', 'ĠÙĬÙĪØ³', 'ĠØ³Ø¨ØŃ', 'ĠØ§ÙĦÙĦØ¬']
#   Position 81 (Correct: 'assistant')    ['áĲĪ', 'Ġáº¤', 'áĲī', 'ĠØ§ÙĦØ£ÙĪØ±ÙĪ', 'ĠØ§ÙĦÙĦØ¬']
#   Position 82 (Correct: 'Ċ')            ['áĲĪ', 'Ġáº¤', 'ĠÙĬÙĪØ³', 'ĠØ§ÙĦÙĦØ¬', 'ĠØ³Ø¨ØŃ']
#
# Layer 28:
#   Position 0 (Correct: '[SPECIAL_151644]') ['Ġsoft', 'Ġsubtle', 'Ġshadows', 'Ġtheir', 'Ġslight']
#   Position 1 (Correct: 'system')       ['Ġor', 'Ġcontext', ':', ',', 'Ġand']
#   Position 2 (Correct: 'Ċ')            ['Ġand', ',', 'Ġwith', '.', 'ical']
#   Position 3 (Correct: 'You')          ['Ġof', 'Ġand', ',', 'Ġcenter', 'Ġa']
#   Position 4 (Correct: 'Ġare')         ['Ġand', ',', 'Ġdistinct', 'Ġbright', 'Ġdistinctly']
#   Position 5 (Correct: 'Ġa')           ['Ġand', ',', 'Ġwith', 'Ġreflective', '-looking']
#   Position 6 (Correct: 'Ġhelpful')     ['Ġobjects', ',', 'Ġand', 'Ġitems', 'Ġfigures']
#   Position 7 (Correct: 'Ġassistant')   ['Ġin', 'Ġscene', 'Ġobjects', 'Ġcomposition', 'Ġimage']
#   Position 33 (Correct: 'A')            [')', '.', ':', ').', 'Ġcylinder']
#   Position 34 (Correct: '.')            ['Ġcylinder', 'Ġpurple', 'Ġrubber', 'ĠCylinder', 'ĠA']
#   Position 35 (Correct: 'ĠA')           ['Ġpurple', 'Ġgreen', 'Ġcylinder', 'Ġsmall', 'Ġred']
#   Position 36 (Correct: 'Ġphoto')       ['Ġof', 'Ġtaken', 'Ċ', '-real', 'Ġwith']
#   Position 37 (Correct: 'Ġof')          ['Ġa', 'Ġtwo', 'Ġpurple', 'Ġobjects', 'Ġan']
#   Position 38 (Correct: 'Ġa')           ['Ġpurple', 'Ġcylinder', 'Ġtoy', 'Ġcup', 'Ġgreen']
#   Position 39 (Correct: 'Ġcylinder')    ['Ġand', ',', 'Ċ', 'Ġon', '.Ċ']
#   Position 40 (Correct: 'Ġright')       ['Ġnext', 'Ġof', 'Ġbeside', 'Ġand', 'Ġin']
#   Position 41 (Correct: 'Ġof')          ['Ġa', 'Ġthe', 'Ġgreen', 'Ġcone', 'Ġan']
#   Position 42 (Correct: 'Ġa')           ['Ġcone', 'Ġgreen', 'Ġpurple', 'Ġsmall', 'Ġcylinder']
#   Position 43 (Correct: 'Ġcone')        ['.Ċ', 'Ċ', 'Ġon', 'Ġin', ',']
#   Position 44 (Correct: 'Ċ')            ['B', 'A', 'C', 'D', 'G']
#   Position 45 (Correct: 'B')            ['.', ':', ',', ')', '.A']
#   Position 46 (Correct: '.')            ['ĠA', 'ĠAn', 'ĠTwo', 'ĠPhoto', 'ĠImage']
#   Position 47 (Correct: 'ĠA')           ['Ġphoto', 'Ġ', 'Ġpurple', 'Ġrendering', 'Ġrender']
#   Position 48 (Correct: 'Ġphoto')       ['Ġof', 'Ġshowing', 'Ġwith', 'Ġtaken', 'Ġthat']
#   Position 49 (Correct: 'Ġof')          ['Ġa', 'Ġtwo', 'Ġobjects', 'Ġan', 'Ġcylinders']
#   Position 50 (Correct: 'Ġa')           ['Ġcylinder', 'Ġcone', 'Ġpurple', 'Ġgreen', 'Ġcube']
#   Position 51 (Correct: 'Ġcone')        ['Ġright', 'Ġleft', 'Ġand', 'Ġon', 'Ġnext']
#   Position 52 (Correct: 'Ġright')       ['Ġof', 'Ġand', 'Ġside', 'Ġnext', 'Ġto']
#   Position 53 (Correct: 'Ġof')          ['Ġa', 'Ġthe', 'Ġanother', 'Ġits', 'Ġan']
#   Position 54 (Correct: 'Ġa')           ['Ġcylinder', 'Ġpurple', 'Ġcube', 'Ġsphere', 'Ġcyan']
#   Position 55 (Correct: 'Ġcylinder')    ['Ċ', '.Ċ', 'ĠĊ', ',', 'Ġwith']
#   Position 56 (Correct: 'Ċ')            ['C', 'B', 'Answer', 'The', 'A']
#   Position 57 (Correct: 'C')            ['.', ')', '.A', ',', '-']
#   Position 58 (Correct: '.')            ['ĠA', 'ĠAn', 'ĠThe', 'ĠBoth', 'ĠCylinder']
#   Position 59 (Correct: 'ĠA')           ['Ġphoto', 'Ġ', 'Ġdrawing', 'Ġpurple', 'Ġrendering']
#   Position 60 (Correct: 'Ġphoto')       ['Ġof', 'Ġwith', 'Ġshowing', 'Ġcontaining', 'Ġthat']
#   Position 61 (Correct: 'Ġof')          ['Ġa', 'Ġtwo', 'Ġonly', 'Ġobjects', 'Ġan']
#   Position 62 (Correct: 'Ġa')           ['Ġcylinder', 'Ġpurple', 'Ġcone', 'Ġgreen', 'Ġsphere']
#   Position 63 (Correct: 'Ġcone')        ['Ġleft', 'Ġand', 'Ġabove', 'Ġon', 'Ġright']
#   Position 64 (Correct: 'Ġleft')        ['Ġof', 'Ġto', 'Ġand', 'Ġside', 'Ġa']
#   Position 65 (Correct: 'Ġof')          ['Ġa', 'Ġthe', 'Ġanother', 'Ġan', 'Ġcylinder']
#   Position 66 (Correct: 'Ġa')           ['Ġcylinder', 'Ġsphere', 'Ġcube', 'Ġpurple', 'Ġcone']
#   Position 67 (Correct: 'Ġcylinder')    ['Ċ', 'ĠĊ', '.Ċ', '[SPECIAL_151645]', 'ĠB']
#   Position 68 (Correct: 'Ċ')            ['D', 'Answer', 'A', 'C', 'B']
#   Position 69 (Correct: 'Answer')       [':', ':B', ':Ċ', 'ĠB', 'Ċ']
#   Position 70 (Correct: 'Ġwith')        ['Ġeither', 'Ġthe', 'Ġonly', 'Ġjust', 'ĠB']
#   Position 71 (Correct: 'Ġthe')         ['Ġcorrect', 'Ġletter', 'Ġlabel', 'Ġcorresponding', 'Ġnumber']
#   Position 72 (Correct: 'Ġletter')      ['Ġof', 'ĠB', 'Ġcorresponding', 'Ġ(', 'Ġthat']
#   Position 73 (Correct: 'Ġof')          ['Ġthe', 'Ġyour', 'Ġcorrect', 'Ġchoice', 'Ġeach']
#   Position 74 (Correct: 'Ġthe')         ['Ġcorrect', 'Ġlabel', 'Ġchoice', 'Ġchosen', 'Ġoption']
#   Position 75 (Correct: 'Ġcorrect')     ['Ġlabel', 'Ġchoice', 'Ġoption', 'Ġanswer', 'Ġdescription']
#   Position 76 (Correct: 'Ġchoice')      ['.', ':', '[SPECIAL_151645]', 'Ġ(', ',']
#   Position 77 (Correct: '.')            ['[SPECIAL_151645]', 'ĠB', 'ĠĊ', 'ĠThe', 'ĠĠĊ']
#   Position 78 (Correct: '[SPECIAL_151645]') ['B', 'ĠB', '(B', '.B', ':B']
#   Position 79 (Correct: 'Ċ')            ['B', 'A', 'C', 'None', 'Answer']
#   Position 80 (Correct: '[SPECIAL_151644]') ['B', 'ĠB', '[SPECIAL_151645]', 'A', 'Ġcylinder']
#   Position 81 (Correct: 'assistant')    ['ĠB', 'B', 'ĠThe', 'The', 'ĠBased']
#   Position 82 (Correct: 'Ċ')            ['B', 'The', 'A', 'D', 'C']

# %% [markdown]
# ## Show special tokens

# %%
# Get special tokens and flatten any lists in special_tokens_map.values()
special_tokens = []
for value in text_tokenizer.special_tokens_map.values():
    if isinstance(value, list):
        special_tokens.extend(value)  # Flatten lists (e.g., additional_special_tokens)
    else:
        special_tokens.append(value)  # Add single tokens
special_tokens = list(set(special_tokens))
# Get token IDs for each special token
special_tokens_with_ids = [(token, text_tokenizer.convert_tokens_to_ids(token)) for token in special_tokens]

# Print special tokens with their IDs
print("Special tokens with IDs:")
for token, token_id in special_tokens_with_ids:
    print(f"  ID: {token_id}, Token: {token}")
# Out:
# Special tokens with IDs:
#   ID: 151646, Token: <|object_ref_start|>
#   ID: 151649, Token: <|box_end|>
#   ID: 151647, Token: <|object_ref_end|>
#   ID: 151654, Token: <|vision_pad|>
#   ID: 151656, Token: <|video_pad|>
#   ID: 151645, Token: <|im_end|>
#   ID: 151651, Token: <|quad_end|>
#   ID: 151650, Token: <|quad_start|>
#   ID: 151643, Token: <|endoftext|>
#   ID: 151652, Token: <|vision_start|>
#   ID: 151653, Token: <|vision_end|>
#   ID: 151655, Token: <|image_pad|>
#   ID: 151648, Token: <|box_start|>
#   ID: 151644, Token: <|im_start|>

# %%
print(model)
# Out:
# Ovis(
#   (llm): Qwen2ForCausalLM(
#     (model): Qwen2Model(
#       (embed_tokens): Embedding(152064, 3584)
#       (layers): ModuleList(
#         (0-27): 28 x Qwen2DecoderLayer(
#           (self_attn): Qwen2Attention(
#             (q_proj): Linear(in_features=3584, out_features=3584, bias=True)
#             (k_proj): Linear(in_features=3584, out_features=512, bias=True)
#             (v_proj): Linear(in_features=3584, out_features=512, bias=True)
#             (o_proj): Linear(in_features=3584, out_features=3584, bias=False)
#           )
#           (mlp): Qwen2MLP(
#             (gate_proj): Linear(in_features=3584, out_features=18944, bias=False)
#             (up_proj): Linear(in_features=3584, out_features=18944, bias=False)
#             (down_proj): Linear(in_features=18944, out_features=3584, bias=False)
#             (act_fn): SiLU()
#           )
#           (input_layernorm): Qwen2RMSNorm((3584,), eps=1e-06)
#           (post_attention_layernorm): Qwen2RMSNorm((3584,), eps=1e-06)
#         )
#       )
#       (norm): Qwen2RMSNorm((3584,), eps=1e-06)
#       (rotary_emb): Qwen2RotaryEmbedding()
#     )
#     (lm_head): Linear(in_features=3584, out_features=152064, bias=False)
#   )
#   (visual_tokenizer): Aimv2VisualTokenizer(
#     (backbone): AIMv2Model(
#       (preprocessor): AIMv2ViTPreprocessor(
#         (patchifier): AIMv2PatchEmbed(
#           (proj): Conv2d(3, 1536, kernel_size=(14, 14), stride=(14, 14))
#           (norm): RMSNorm((1536,), eps=1e-05)
#         )
#       )
#       (trunk): AIMv2Transformer(
#         (blocks): ModuleList(
#           (0-23): 24 x AIMv2Block(
#             (attn): AIMv2Attention(
#               (qkv): Linear(in_features=1536, out_features=4608, bias=False)
#               (attn_drop): Dropout(p=0.0, inplace=False)
#               (proj): Linear(in_features=1536, out_features=1536, bias=False)
#               (proj_drop): Dropout(p=0.0, inplace=False)
#             )
#             (norm_1): RMSNorm((1536,), eps=1e-05)
#             (mlp): AIMv2SwiGLUFFN(
#               (fc1): Linear(in_features=1536, out_features=4096, bias=False)
#               (fc2): Linear(in_features=4096, out_features=1536, bias=False)
#               (fc3): Linear(in_features=1536, out_features=4096, bias=False)
#             )
#             (norm_2): RMSNorm((1536,), eps=1e-05)
#           )
#         )
#         (post_trunk_norm): RMSNorm((1536,), eps=1e-05)
#       )
#     )
#     (head): Sequential(
#       (0): Linear(in_features=6144, out_features=65531, bias=False)
#       (1): LayerNorm((65531,), eps=1e-05, elementwise_affine=True)
#     )
#   )
#   (vte): VisualEmbedding(65536, 3584)
# )
