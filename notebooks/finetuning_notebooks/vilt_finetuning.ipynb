# %%
import os
import random
from PIL import Image
import tqdm
import numpy as np
import pandas as pd
import csv
import time
from datetime import datetime
import pytz

import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from torchvision.datasets import ImageFolder
import torchvision.transforms as transforms

from peft import LoraConfig, get_peft_model
from transformers import ViltProcessor, ViltForImageAndTextRetrieval

# %%
from transformers.utils import logging
logging.set_verbosity_error()

import warnings
warnings.filterwarnings("ignore")

os.environ["WANDB_DISABLED"] = "true"

# %%
def create_distractors_single_object(true_label):
    shapes = ['cube', 'sphere', 'cone', 'cylinder']
    colors = ['blue', 'brown', 'cyan', 'gray', 'green', 'purple', 'red', 'yellow']

    all_labels = [f"A photo of a {color} {shape}" for shape in shapes for color in colors]
    all_labels.remove(true_label)

    random_labels = random.sample(all_labels, k=4)

    return random_labels

# %%
def create_distractors_two_object(true_labels):
    shapes = ['cube', 'sphere', 'cone', 'cylinder']
    colors = ['blue', 'brown', 'cyan', 'gray', 'green', 'purple', 'red', 'yellow']

    _, _, _, _, color1, shape1 = true_labels[0].split()
    _, _, _, _, color2, shape2 = true_labels[1].split()

    hard_distractors = [f"A photo of a {color1} {shape2}", f"A photo of a {color2} {shape1}"]

    exclude = set(true_labels + tuple(hard_distractors))
    all_labels = [f"A photo of a {color} {shape}" for shape in shapes for color in colors if f"A photo of a {color} {shape}" not in exclude]
    random_labels = random.sample(all_labels, k=4-len(hard_distractors))

    return hard_distractors + random_labels

# %%
def create_distractors_relational(true_label):
    shapes = ['cube', 'sphere', 'cone', 'cylinder']
    relations = {'right': 'left', 'left': 'right'}

    true_parts = true_label.split()
    _, _, _, _, true_shape1, true_relation, _, _, true_shape2 = true_parts  # e.g., 'a', 'photo, 'of', 'a', 'sphere', 'right', 'of', 'a', 'cube'

    # Define hard distractors
    # 1. Shape-swapped: Swap true_shape1 and true_shape2
    shape_swapped = f"A photo of a {true_shape2} {true_relation} of a {true_shape1}"
    # 2. Relation-swapped: Use opposite relation
    relation_swapped = f"A photo of a {true_shape1} {relations[true_relation]} of a {true_shape2}"

    hard_distractors = [shape_swapped, relation_swapped]

    # Generate all possible labels
    all_labels = [f"A photo of a {shape} {rel} of a {other_shape}"
                  for shape in shapes
                  for rel in relations
                  for other_shape in shapes if other_shape != shape]

    # Define the inverse label (already true and must be excluded)
    inverse_label = f" A photo of a {true_shape2} {relations[true_relation]} of a {true_shape1}"

    # Filter out true label, inverse label, and ensure hard distractors are unique
    exclude = {true_label, inverse_label}
    filtered_labels = [label for label in all_labels if label not in exclude]

    # Sample random distractors, excluding hard distractors if they’re already in filtered_labels
    random_labels = random.sample([label for label in filtered_labels if label not in hard_distractors], k=4-len(hard_distractors))

    return hard_distractors + random_labels

# %%
class CustomDataset(ImageFolder):
    def __init__(self, root, dataset_name, transform=None):
        super().__init__(root, transform=transform)
        self.dataset_name = dataset_name

    def find_classes(self, directory):
        classes = [d.name for d in os.scandir(directory) if d.is_dir() and not d.name.startswith('.')]
        classes.sort()
        if not classes:
            raise FileNotFoundError(f"Couldn't find any valid class folders in {directory}")
        class_to_idx = {cls_name: i for i, cls_name in enumerate(classes)}
        # print('classes:', classes)
        return classes, class_to_idx

    def __getitem__(self, index):
        path, target = self.samples[index]
        image = self.loader(path)  # Load as PIL Image
        correct_label = self.classes[target]

        if self.dataset_name == 'single_object':
            parts = correct_label.split('_')
            correct_label = f'A photo of a {parts[0]} {parts[1]}'
            labels_list = [correct_label] + create_distractors_single_object(correct_label)
        elif self.dataset_name == 'two_object':
            parts = correct_label.split('_')
            correct_label = f"A photo of a {parts[0]} {parts[1]}"
            filler_label = f"A photo of a {parts[2]} {parts[3]}"
            labels_list = [correct_label] + create_distractors_two_object((correct_label, filler_label))
        elif self.dataset_name == 'relational':
            parts = correct_label.split('_')
            correct_label = f"A photo of a {parts[0]} {parts [1]} of a {parts[2]}"
            labels_list = [correct_label] + create_distractors_relational(correct_label)

        random.shuffle(labels_list)
        correct_index = labels_list.index(correct_label)

        return image, labels_list, correct_index

# %%
import os
import random
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from transformers import ViltForImageAndTextRetrieval, ViltProcessor
from peft import LoraConfig, get_peft_model
from datetime import datetime
import pytz
import matplotlib.pyplot as plt
from itertools import product
import uuid

def train_and_evaluate(dataset_name, base_path='/home/bboulbarss/large_dataset', seed=42):
    # Set seeds for reproducibility
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

    # Define paths for train, validation, and test splits
    train_root = os.path.join(base_path, dataset_name, 'train')
    val_ood_root = os.path.join(base_path, dataset_name, 'ood_val')

    # Rename directories to replace spaces with underscores
    for dir_name in os.listdir(train_root):
        if ' ' in dir_name:
            new_name = dir_name.replace(' ', '_')
            os.rename(
                os.path.join(train_root, dir_name),
                os.path.join(train_root, new_name)
            )
    for dir_name in os.listdir(val_ood_root):
        if ' ' in dir_name:
            new_name = dir_name.replace(' ', '_')
            os.rename(
                os.path.join(val_ood_root, dir_name),
                os.path.join(val_ood_root, new_name)
            )

    # Create datasets
    train_dataset = CustomDataset(root=train_root, dataset_name=dataset_name)
    val_ood_dataset = CustomDataset(root=val_ood_root, dataset_name=dataset_name)

    # Define hyperparameter grid
    batch_size = 32
    lora_rs = [(8, 16), (16, 32)]
    learning_rates = [1e-6, 1e-5]

    # Initialize variables to track the best model
    best_accuracy = 0.0
    best_model_path = None
    best_processor_path = None
    best_hyperparams = None
    best_train_losses = []
    timestamp = datetime.now(pytz.timezone('Europe/Amsterdam')).strftime('%Y%m%d_%H%M%S')

    # Grid search over hyperparameters
    for lora_r, lr in product(lora_rs, learning_rates):
        print(f"\nTesting hyperparameters: lora_r={lora_r}, lr={lr}")

        # Create data loaders
        train_loader = DataLoader(
            train_dataset, 
            batch_size=batch_size, 
            shuffle=True, 
            collate_fn=lambda x: x, 
            num_workers=0, 
            pin_memory=True
        )
        val_ood_loader = DataLoader(
            val_ood_dataset, 
            batch_size=batch_size, 
            shuffle=False, 
            collate_fn=lambda x: x, 
            num_workers=0, 
            pin_memory=True
        )

        # Load the base ViLT model and processor
        model = ViltForImageAndTextRetrieval.from_pretrained("dandelin/vilt-b32-finetuned-coco")
        processor = ViltProcessor.from_pretrained("dandelin/vilt-b32-finetuned-coco")
        device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        model.to(device)

        # Apply LoRA
        lora_config = LoraConfig(
            r=lora_r[0],
            lora_alpha=lora_r[1],
            lora_dropout=0.5,
            bias="none",
            target_modules="all-linear"
        )
        peft_model = get_peft_model(model, lora_config)
        for name, param in peft_model.named_parameters():
            if "lora" not in name.lower():
                param.requires_grad = False
        model = peft_model
        model.to(device)

        # Set up optimizer
        optimizer = torch.optim.AdamW(
            filter(lambda p: p.requires_grad, model.parameters()), 
            lr=lr, 
            weight_decay=0.1
        )

        num_epochs = 15
        patience = 3
        epochs_no_improve = 0
        current_best_accuracy = 0.0
        train_losses = []

        for epoch in range(num_epochs):
            model.train()
            total_loss = 0.0
            for i, batch in enumerate(train_loader):
                images, texts_lists, correct_indices = zip(*batch)
                texts = [text for texts_list in texts_lists for text in texts_list]

                batch_images = []
                batch_texts = []
                for img, texts in zip(images, texts_lists):
                    batch_images.extend([img] * 5)
                    batch_texts.extend(texts)

                inputs = processor(
                    images=batch_images,
                    text=batch_texts,
                    return_tensors="pt",
                    padding=True,
                    truncation=True
                ).to(device)

                outputs = model(**inputs)
                logits = outputs.logits.squeeze()
                B = len(images)
                logits_per_image = logits.view(B, 5)

                correct_indices_tensor = torch.tensor(correct_indices, device=device)
                loss = nn.CrossEntropyLoss()(logits_per_image, correct_indices_tensor)
                total_loss += loss.item()

                optimizer.zero_grad()
                loss.backward()
                optimizer.step()

                if i % 10 == 0:
                    print(f"Epoch {epoch+1}, Batch {i}, Loss: {loss.item():.4f}")

            avg_loss = total_loss / len(train_loader)
            train_losses.append(avg_loss)
            print(f"Epoch {epoch+1} completed, Average Training Loss: {avg_loss:.4f}")

            # Validation phase
            model.eval()
            correct = 0
            total = 0
            with torch.no_grad():
                print("Start OOD Validation Phase")
                for batch in val_ood_loader:
                    images, texts_lists, correct_indices = zip(*batch)
                    batch_images = []
                    batch_texts = []
                    for img, texts in zip(images, texts_lists):
                        batch_images.extend([img] * 5)
                        batch_texts.extend(texts)

                    inputs = processor(
                        images=batch_images,
                        text=batch_texts,
                        return_tensors="pt",
                        padding=True,
                        truncation=True
                    ).to(device)

                    outputs = model(**inputs)
                    logits = outputs.logits.squeeze()
                    B = len(images)
                    logits_per_image = logits.view(B, 5)
                    preds = logits_per_image.argmax(dim=1)
                    correct += (preds == torch.tensor(correct_indices, device=device)).sum().item()
                    total += B

                accuracy_ood = correct / total
                print(f"Validation (OOD) Accuracy for {dataset_name}: {accuracy_ood:.4f}")

                # Save best model based on OOD validation
                if accuracy_ood > current_best_accuracy:
                    current_best_accuracy = accuracy_ood
                    epochs_no_improve = 0
                else:
                    epochs_no_improve += 1

                # Update global best model if current model is better
                if accuracy_ood > best_accuracy:
                    best_accuracy = accuracy_ood
                    best_hyperparams = {'batch_size': batch_size, 'lora_r': lora_r, 'lr': lr}
                    best_train_losses = train_losses.copy()
                    model_save_dir = '/home/bboulbarss/finetuned_models/vilt'
                    os.makedirs(model_save_dir, exist_ok=True)
                    best_model_path = os.path.join(
                        model_save_dir, 
                        f'vilt_lora_best_{dataset_name}_{seed}_{timestamp}_{lora_r}_{batch_size}_{lr}'
                    )
                    best_processor_path = os.path.join(
                        model_save_dir, 
                        f'vilt_processor_best_{dataset_name}_{seed}_{timestamp}_{lora_r}_{batch_size}_{lr}'
                    )
                    model.save_pretrained(best_model_path)
                    processor.save_pretrained(best_processor_path)

            if epochs_no_improve >= patience:
                print(f"Early stopping at epoch {epoch+1}")
                break

    # Plot training loss curve for the best model
    plt.figure(figsize=(10, 6))
    plt.plot(range(1, len(best_train_losses) + 1), best_train_losses, marker='o', linestyle='-', color='b')
    plt.title(f'Training Loss Curve for Best Model\nDataset: {dataset_name}, '
              f'Hyperparameters: {best_hyperparams}')
    plt.xlabel('Epoch')
    plt.ylabel('Average Training Loss')
    plt.grid(True)
    plt.savefig(os.path.join(model_save_dir, f'training_loss_curve_{dataset_name}_{seed}_{timestamp}.png'))
    plt.close()

    print(f"\nBest Model Hyperparameters: {best_hyperparams}")
    print(f"Best Validation (OOD) Accuracy: {best_accuracy:.4f}")
    print(f"Best LoRA adapter saved to: {best_model_path}")
    print(f"Processor saved to: {best_processor_path}")
    print(f"Training loss curve saved to: {model_save_dir}/training_loss_curve_{dataset_name}_{seed}_{timestamp}.png")

# %%
datasets = ['single_object'] #'single_object', 'relational', 'two_object'
for dataset in datasets:
    print(f"\nTraining on {dataset}")
    train_and_evaluate(dataset, seed=42)
# Out:
# Training on single_object
#
# Testing hyperparameters: lora_r=(8, 16), lr=1e-06
# Epoch 1, Batch 0, Loss: 0.2802
# Epoch 1, Batch 10, Loss: 0.8824
# Epoch 1, Batch 20, Loss: 0.5683
# Epoch 1, Batch 30, Loss: 0.5757
# Epoch 1, Batch 40, Loss: 0.4259
# Epoch 1 completed, Average Training Loss: 0.5225
# Start OOD Validation Phase
# Validation (OOD) Accuracy for single_object: 0.7850
# Epoch 2, Batch 0, Loss: 0.6260
# Epoch 2, Batch 10, Loss: 0.6077
# Epoch 2, Batch 20, Loss: 0.5897
# Epoch 2, Batch 30, Loss: 0.2749
# Epoch 2, Batch 40, Loss: 0.5426
# Epoch 2 completed, Average Training Loss: 0.5204
# Start OOD Validation Phase
# Validation (OOD) Accuracy for single_object: 0.7475
# Epoch 3, Batch 0, Loss: 0.4712
# Epoch 3, Batch 10, Loss: 0.6285
# Epoch 3, Batch 20, Loss: 0.5427
# Epoch 3, Batch 30, Loss: 0.9620
# Epoch 3, Batch 40, Loss: 0.6457
# Epoch 3 completed, Average Training Loss: 0.5133
# Start OOD Validation Phase
# Validation (OOD) Accuracy for single_object: 0.7325
# Epoch 4, Batch 0, Loss: 0.6707
# Epoch 4, Batch 10, Loss: 0.5077
# Epoch 4, Batch 20, Loss: 0.4077
# Epoch 4, Batch 30, Loss: 0.8160
# Epoch 4, Batch 40, Loss: 0.5748
# Epoch 4 completed, Average Training Loss: 0.5136
# Start OOD Validation Phase
# Validation (OOD) Accuracy for single_object: 0.7750
# Early stopping at epoch 4
#
# Testing hyperparameters: lora_r=(8, 16), lr=1e-05
# Epoch 1, Batch 0, Loss: 0.4205
# Epoch 1, Batch 10, Loss: 0.5910
# Epoch 1, Batch 20, Loss: 0.9364
# Epoch 1, Batch 30, Loss: 0.4410
# Epoch 1, Batch 40, Loss: 0.4612
# Epoch 1 completed, Average Training Loss: 0.5269
# Start OOD Validation Phase
# Validation (OOD) Accuracy for single_object: 0.7825
# Epoch 2, Batch 0, Loss: 0.8191
# Epoch 2, Batch 10, Loss: 0.6263
# Epoch 2, Batch 20, Loss: 0.5576
# Epoch 2, Batch 30, Loss: 0.3559
# Epoch 2, Batch 40, Loss: 0.3056
# Epoch 2 completed, Average Training Loss: 0.4486
# Start OOD Validation Phase
# Validation (OOD) Accuracy for single_object: 0.8275
# Epoch 3, Batch 0, Loss: 0.4672
# Epoch 3, Batch 10, Loss: 0.4281
# Epoch 3, Batch 20, Loss: 0.5391
# Epoch 3, Batch 30, Loss: 0.4706
# Epoch 3, Batch 40, Loss: 0.3468
# Epoch 3 completed, Average Training Loss: 0.3788
# Start OOD Validation Phase
# Validation (OOD) Accuracy for single_object: 0.8375
# Epoch 4, Batch 0, Loss: 0.3806
# Epoch 4, Batch 10, Loss: 0.1827
# Epoch 4, Batch 20, Loss: 0.3045
# Epoch 4, Batch 30, Loss: 0.4121
# Epoch 4, Batch 40, Loss: 0.1400
# Epoch 4 completed, Average Training Loss: 0.3085
# Start OOD Validation Phase
# Validation (OOD) Accuracy for single_object: 0.8900
# Epoch 5, Batch 0, Loss: 0.2505
# Epoch 5, Batch 10, Loss: 0.3273
# Epoch 5, Batch 20, Loss: 0.2033
# Epoch 5, Batch 30, Loss: 0.2803
# Epoch 5, Batch 40, Loss: 0.1848
# Epoch 5 completed, Average Training Loss: 0.2606
# Start OOD Validation Phase
# Validation (OOD) Accuracy for single_object: 0.9025
# Epoch 6, Batch 0, Loss: 0.1661
# Epoch 6, Batch 10, Loss: 0.2012
# Epoch 6, Batch 20, Loss: 0.2001
# Epoch 6, Batch 30, Loss: 0.2155
# Epoch 6, Batch 40, Loss: 0.1821
# Epoch 6 completed, Average Training Loss: 0.2075
# Start OOD Validation Phase
# Validation (OOD) Accuracy for single_object: 0.8875
# Epoch 7, Batch 0, Loss: 0.1870
# Epoch 7, Batch 10, Loss: 0.1830
# Epoch 7, Batch 20, Loss: 0.1134
# Epoch 7, Batch 30, Loss: 0.1333
# Epoch 7, Batch 40, Loss: 0.1693
# Epoch 7 completed, Average Training Loss: 0.1806
# Start OOD Validation Phase
# Validation (OOD) Accuracy for single_object: 0.9050
# Epoch 8, Batch 0, Loss: 0.1179
# Epoch 8, Batch 10, Loss: 0.0805
# Epoch 8, Batch 20, Loss: 0.1867
# Epoch 8, Batch 30, Loss: 0.1499
# Epoch 8, Batch 40, Loss: 0.1213
# Epoch 8 completed, Average Training Loss: 0.1375
# Start OOD Validation Phase
# Validation (OOD) Accuracy for single_object: 0.9325
# Epoch 9, Batch 0, Loss: 0.1552
# Epoch 9, Batch 10, Loss: 0.0854
# Epoch 9, Batch 20, Loss: 0.1448
# Epoch 9, Batch 30, Loss: 0.1672
# Epoch 9, Batch 40, Loss: 0.0612
# Epoch 9 completed, Average Training Loss: 0.1170
# Start OOD Validation Phase
# Validation (OOD) Accuracy for single_object: 0.9325
# Epoch 10, Batch 0, Loss: 0.0418
# Epoch 10, Batch 10, Loss: 0.0781
# Epoch 10, Batch 20, Loss: 0.1404
# Epoch 10, Batch 30, Loss: 0.1217
# Epoch 10, Batch 40, Loss: 0.0277
# Epoch 10 completed, Average Training Loss: 0.0984
# Start OOD Validation Phase
# Validation (OOD) Accuracy for single_object: 0.9175
# Epoch 11, Batch 0, Loss: 0.1012
# Epoch 11, Batch 10, Loss: 0.0653
# Epoch 11, Batch 20, Loss: 0.0422
# Epoch 11, Batch 30, Loss: 0.0634
# Epoch 11, Batch 40, Loss: 0.0281
# Epoch 11 completed, Average Training Loss: 0.0782
# Start OOD Validation Phase
# Validation (OOD) Accuracy for single_object: 0.9225
# Early stopping at epoch 11
#
# Testing hyperparameters: lora_r=(16, 32), lr=1e-06
# Epoch 1, Batch 0, Loss: 0.4214
# Epoch 1, Batch 10, Loss: 0.5850
# Epoch 1, Batch 20, Loss: 0.4667
# Epoch 1, Batch 30, Loss: 0.4396
# Epoch 1, Batch 40, Loss: 0.4692
# Epoch 1 completed, Average Training Loss: 0.5257
# Start OOD Validation Phase
# Validation (OOD) Accuracy for single_object: 0.7775
# Epoch 2, Batch 0, Loss: 0.3538
# Epoch 2, Batch 10, Loss: 0.3157
# Epoch 2, Batch 20, Loss: 0.7590
# Epoch 2, Batch 30, Loss: 0.4112
# Epoch 2, Batch 40, Loss: 0.4815
# Epoch 2 completed, Average Training Loss: 0.4949
# Start OOD Validation Phase
# Validation (OOD) Accuracy for single_object: 0.7775
# Epoch 3, Batch 0, Loss: 0.5856
# Epoch 3, Batch 10, Loss: 0.3233
# Epoch 3, Batch 20, Loss: 0.3600
# Epoch 3, Batch 30, Loss: 0.6715
# Epoch 3, Batch 40, Loss: 0.5460
# Epoch 3 completed, Average Training Loss: 0.4927
# Start OOD Validation Phase
# Validation (OOD) Accuracy for single_object: 0.7675
# Epoch 4, Batch 0, Loss: 1.0169
# Epoch 4, Batch 10, Loss: 0.2714
# Epoch 4, Batch 20, Loss: 0.4053
# Epoch 4, Batch 30, Loss: 0.4795
# Epoch 4, Batch 40, Loss: 0.2476
# Epoch 4 completed, Average Training Loss: 0.4821
# Start OOD Validation Phase
# Validation (OOD) Accuracy for single_object: 0.8025
# Epoch 5, Batch 0, Loss: 0.6312
# Epoch 5, Batch 10, Loss: 0.7170
# Epoch 5, Batch 20, Loss: 0.3372
# Epoch 5, Batch 30, Loss: 0.7295
# Epoch 5, Batch 40, Loss: 0.3826
# Epoch 5 completed, Average Training Loss: 0.4766
# Start OOD Validation Phase
# Validation (OOD) Accuracy for single_object: 0.8100
# Epoch 6, Batch 0, Loss: 0.3334
# Epoch 6, Batch 10, Loss: 0.4869
# Epoch 6, Batch 20, Loss: 0.3942
# Epoch 6, Batch 30, Loss: 0.3699
# Epoch 6, Batch 40, Loss: 0.4206
# Epoch 6 completed, Average Training Loss: 0.4515
# Start OOD Validation Phase
# Validation (OOD) Accuracy for single_object: 0.7900
# Epoch 7, Batch 0, Loss: 0.3640
# Epoch 7, Batch 10, Loss: 0.3875
# Epoch 7, Batch 20, Loss: 0.3519
# Epoch 7, Batch 30, Loss: 0.7058
# Epoch 7, Batch 40, Loss: 0.4305
# Epoch 7 completed, Average Training Loss: 0.4619
# Start OOD Validation Phase
# Validation (OOD) Accuracy for single_object: 0.7875
# Epoch 8, Batch 0, Loss: 0.8012
# Epoch 8, Batch 10, Loss: 0.5114
# Epoch 8, Batch 20, Loss: 0.8542
# Epoch 8, Batch 30, Loss: 0.2923
# Epoch 8, Batch 40, Loss: 0.3993
# Epoch 8 completed, Average Training Loss: 0.4502
# Start OOD Validation Phase
# Validation (OOD) Accuracy for single_object: 0.8075
# Early stopping at epoch 8
#
# Testing hyperparameters: lora_r=(16, 32), lr=1e-05
# Epoch 1, Batch 0, Loss: 0.6221
# Epoch 1, Batch 10, Loss: 0.4970
# Epoch 1, Batch 20, Loss: 0.4732
# Epoch 1, Batch 30, Loss: 0.5615
# Epoch 1, Batch 40, Loss: 0.3352
# Epoch 1 completed, Average Training Loss: 0.4857
# Start OOD Validation Phase
# Validation (OOD) Accuracy for single_object: 0.7850
# Epoch 2, Batch 0, Loss: 0.3135
# Epoch 2, Batch 10, Loss: 0.2980
# Epoch 2, Batch 20, Loss: 0.3259
# Epoch 2, Batch 30, Loss: 0.5534
# Epoch 2, Batch 40, Loss: 0.2313
# Epoch 2 completed, Average Training Loss: 0.3569
# Start OOD Validation Phase
# Validation (OOD) Accuracy for single_object: 0.8725
# Epoch 3, Batch 0, Loss: 0.4486
# Epoch 3, Batch 10, Loss: 0.2440
# Epoch 3, Batch 20, Loss: 0.2537
# Epoch 3, Batch 30, Loss: 0.2160
# Epoch 3, Batch 40, Loss: 0.2432
# Epoch 3 completed, Average Training Loss: 0.2936
# Start OOD Validation Phase
# Validation (OOD) Accuracy for single_object: 0.8525
# Epoch 4, Batch 0, Loss: 0.3223
# Epoch 4, Batch 10, Loss: 0.1805
# Epoch 4, Batch 20, Loss: 0.1753
# Epoch 4, Batch 30, Loss: 0.2254
# Epoch 4, Batch 40, Loss: 0.1791
# Epoch 4 completed, Average Training Loss: 0.2206
# Start OOD Validation Phase
# Validation (OOD) Accuracy for single_object: 0.8900
# Epoch 5, Batch 0, Loss: 0.2184
# Epoch 5, Batch 10, Loss: 0.1836
# Epoch 5, Batch 20, Loss: 0.1237
# Epoch 5, Batch 30, Loss: 0.1287
# Epoch 5, Batch 40, Loss: 0.1441
# Epoch 5 completed, Average Training Loss: 0.1593
# Start OOD Validation Phase
# Validation (OOD) Accuracy for single_object: 0.8925
# Epoch 6, Batch 0, Loss: 0.3879
# Epoch 6, Batch 10, Loss: 0.1825
# Epoch 6, Batch 20, Loss: 0.0749
# Epoch 6, Batch 30, Loss: 0.1313
# Epoch 6, Batch 40, Loss: 0.1057
# Epoch 6 completed, Average Training Loss: 0.1274
# Start OOD Validation Phase
# Validation (OOD) Accuracy for single_object: 0.9150
# Epoch 7, Batch 0, Loss: 0.1012
# Epoch 7, Batch 10, Loss: 0.0955
# Epoch 7, Batch 20, Loss: 0.0652
# Epoch 7, Batch 30, Loss: 0.0711
# Epoch 7, Batch 40, Loss: 0.0739
# Epoch 7 completed, Average Training Loss: 0.0926
# Start OOD Validation Phase
# Validation (OOD) Accuracy for single_object: 0.9250
# Epoch 8, Batch 0, Loss: 0.0929
# Epoch 8, Batch 10, Loss: 0.0852
# Epoch 8, Batch 20, Loss: 0.1013
# Epoch 8, Batch 30, Loss: 0.0568
# Epoch 8, Batch 40, Loss: 0.0450
# Epoch 8 completed, Average Training Loss: 0.0752
# Start OOD Validation Phase
# Validation (OOD) Accuracy for single_object: 0.9375
# Epoch 9, Batch 0, Loss: 0.1104
# Epoch 9, Batch 10, Loss: 0.0857
# Epoch 9, Batch 20, Loss: 0.0565
# Epoch 9, Batch 30, Loss: 0.0278
# Epoch 9, Batch 40, Loss: 0.0526
# Epoch 9 completed, Average Training Loss: 0.0546
# Start OOD Validation Phase
# Validation (OOD) Accuracy for single_object: 0.9425
# Epoch 10, Batch 0, Loss: 0.0442
# Epoch 10, Batch 10, Loss: 0.0195
# Epoch 10, Batch 20, Loss: 0.0251
# Epoch 10, Batch 30, Loss: 0.0636
# Epoch 10, Batch 40, Loss: 0.0127
# Epoch 10 completed, Average Training Loss: 0.0381
# Start OOD Validation Phase
# Validation (OOD) Accuracy for single_object: 0.9350
# Epoch 11, Batch 0, Loss: 0.0380
# Epoch 11, Batch 10, Loss: 0.0197
# Epoch 11, Batch 20, Loss: 0.0129
# Epoch 11, Batch 30, Loss: 0.0233
# Epoch 11, Batch 40, Loss: 0.0456
# Epoch 11 completed, Average Training Loss: 0.0300
# Start OOD Validation Phase
# Validation (OOD) Accuracy for single_object: 0.9400
# Epoch 12, Batch 0, Loss: 0.0218
# Epoch 12, Batch 10, Loss: 0.0134
# Epoch 12, Batch 20, Loss: 0.0570
# Epoch 12, Batch 30, Loss: 0.0808
# Epoch 12, Batch 40, Loss: 0.0282
# Epoch 12 completed, Average Training Loss: 0.0236
# Start OOD Validation Phase
# Validation (OOD) Accuracy for single_object: 0.9250
# Early stopping at epoch 12
#
# Best Model Hyperparameters: {'batch_size': 32, 'lora_r': (16, 32), 'lr': 1e-05}
# Best Validation (OOD) Accuracy: 0.9425
# Best LoRA adapter saved to: /home/bboulbarss/finetuned_models/vilt/vilt_lora_best_single_object_42_20250523_112846_(16, 32)_32_1e-05
# Processor saved to: /home/bboulbarss/finetuned_models/vilt/vilt_processor_best_single_object_42_20250523_112846_(16, 32)_32_1e-05
# Training loss curve saved to: /home/bboulbarss/finetuned_models/vilt/training_loss_curve_single_object_42_20250523_112846.png
