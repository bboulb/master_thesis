# %%
import os
import random
from PIL import Image
import tqdm
import numpy as np
import pandas as pd
import csv
import time
from datetime import datetime
import pytz

import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from torchvision.datasets import ImageFolder
import torchvision.transforms as transforms

from peft import LoraConfig, get_peft_model
from transformers import FlavaForPreTraining, FlavaProcessor

# %%
from transformers.utils import logging
logging.set_verbosity_error()

import warnings
warnings.filterwarnings("ignore")

os.environ["WANDB_DISABLED"] = "true"

# %%
def create_distractors_single_object(true_label):
    shapes = ['cube', 'sphere', 'cone', 'cylinder']
    colors = ['blue', 'brown', 'cyan', 'gray', 'green', 'purple', 'red', 'yellow']

    all_labels = [f"A photo of a {color} {shape}" for shape in shapes for color in colors]
    all_labels.remove(true_label)

    random_labels = random.sample(all_labels, k=4)

    return random_labels

# %%
def create_distractors_two_object(true_labels):
    shapes = ['cube', 'sphere', 'cone', 'cylinder']
    colors = ['blue', 'brown', 'cyan', 'gray', 'green', 'purple', 'red', 'yellow']

    _, _, _, _, color1, shape1 = true_labels[0].split()
    _, _, _, _, color2, shape2 = true_labels[1].split()

    hard_distractors = [f"A photo of a {color1} {shape2}", f"A photo of a {color2} {shape1}"]

    exclude = set(true_labels + tuple(hard_distractors))
    all_labels = [f"A photo of a {color} {shape}" for shape in shapes for color in colors if f"A photo of a {color} {shape}" not in exclude]
    random_labels = random.sample(all_labels, k=4-len(hard_distractors))

    return hard_distractors + random_labels

# %%
def create_distractors_relational(true_label):
    shapes = ['cube', 'sphere', 'cone', 'cylinder']
    relations = {'right': 'left', 'left': 'right'}

    true_parts = true_label.split()
    _, _, _, _, true_shape1, true_relation, _, _, true_shape2 = true_parts  # e.g., 'a', 'photo, 'of', 'a', 'sphere', 'right', 'of', 'a', 'cube'

    # Define hard distractors
    # 1. Shape-swapped: Swap true_shape1 and true_shape2
    shape_swapped = f"A photo of a {true_shape2} {true_relation} of a {true_shape1}"
    # 2. Relation-swapped: Use opposite relation
    relation_swapped = f"A photo of a {true_shape1} {relations[true_relation]} of a {true_shape2}"

    hard_distractors = [shape_swapped, relation_swapped]

    # Generate all possible labels
    all_labels = [f"A photo of a {shape} {rel} of a {other_shape}"
                  for shape in shapes
                  for rel in relations
                  for other_shape in shapes if other_shape != shape]

    # Define the inverse label (already true and must be excluded)
    inverse_label = f" A photo of a {true_shape2} {relations[true_relation]} of a {true_shape1}"

    # Filter out true label, inverse label, and ensure hard distractors are unique
    exclude = {true_label, inverse_label}
    filtered_labels = [label for label in all_labels if label not in exclude]

    # Sample random distractors, excluding hard distractors if they’re already in filtered_labels
    random_labels = random.sample([label for label in filtered_labels if label not in hard_distractors], k=4-len(hard_distractors))

    return hard_distractors + random_labels

# %%
class CustomDataset(ImageFolder):
    def __init__(self, root, dataset_name, transform=None):
        super().__init__(root, transform=transform)
        self.dataset_name = dataset_name

    def find_classes(self, directory):
        classes = [d.name for d in os.scandir(directory) if d.is_dir() and not d.name.startswith('.')]
        classes.sort()
        if not classes:
            raise FileNotFoundError(f"Couldn't find any valid class folders in {directory}")
        class_to_idx = {cls_name: i for i, cls_name in enumerate(classes)}
        return classes, class_to_idx

    def __getitem__(self, index):
        path, target = self.samples[index]
        image = self.loader(path)  # Load as PIL Image
        correct_label = self.classes[target]

        if self.dataset_name == 'single_object':
            parts = correct_label.split('_')
            correct_label = f'A photo of a {parts[0]} {parts[1]}'
            labels_list = [correct_label] + create_distractors_single_object(correct_label)
        elif self.dataset_name == 'two_object':
            parts = correct_label.split('_')
            correct_label = f"A photo of a {parts[0]} {parts[1]}"
            filler_label = f"A photo of a {parts[2]} {parts[3]}"
            labels_list = [correct_label] + create_distractors_two_object((correct_label, filler_label))
        elif self.dataset_name == 'relational':
            parts = correct_label.split('_')
            correct_label = f"A photo of a {parts[0]} {parts [1]} of a {parts[2]}"
            labels_list = [correct_label] + create_distractors_relational(correct_label)

        random.shuffle(labels_list)
        correct_index = labels_list.index(correct_label)

        return image, labels_list, correct_index

# %%
import os
import random
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from transformers import FlavaForPreTraining, FlavaProcessor
from peft import LoraConfig, get_peft_model
from datetime import datetime
import pytz
import matplotlib.pyplot as plt
from itertools import product
import uuid

def train_and_evaluate(dataset_name, base_path='/home/bboulbarss/large_dataset', seed=42):
    # Set seeds for reproducibility
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

    # Define paths for train, validation, and test splits
    train_root = os.path.join(base_path, dataset_name, 'train')
    val_ood_root = os.path.join(base_path, dataset_name, 'ood_val')

    # Rename directories to replace spaces with underscores
    for dir_name in os.listdir(train_root):
        if ' ' in dir_name:
            new_name = dir_name.replace(' ', '_')
            os.rename(
                os.path.join(train_root, dir_name),
                os.path.join(train_root, new_name)
            )
    for dir_name in os.listdir(val_ood_root):
        if ' ' in dir_name:
            new_name = dir_name.replace(' ', '_')
            os.rename(
                os.path.join(val_ood_root, dir_name),
                os.path.join(val_ood_root, new_name)
            )

    # Create datasets
    train_dataset = CustomDataset(root=train_root, dataset_name=dataset_name)
    val_ood_dataset = CustomDataset(root=val_ood_root, dataset_name=dataset_name)

    # Define hyperparameter grid
    batch_size = 32
    lora_rs = [(8, 16), (16, 32)]
    learning_rates = [1e-6, 1e-5]

    # Initialize variables to track the best model
    best_accuracy = 0.0
    best_model_path = None
    best_processor_path = None
    best_hyperparams = None
    best_train_losses = []
    timestamp = datetime.now(pytz.timezone('Europe/Amsterdam')).strftime('%Y%m%d_%H%M%S')

    # Grid search over hyperparameters
    for lora_r, lr in product(lora_rs, learning_rates):
        print(f"\nTesting hyperparameters: lora_r={lora_r}, lr={lr}")

        # Create data loaders
        train_loader = DataLoader(
            train_dataset, 
            batch_size=batch_size, 
            shuffle=True, 
            collate_fn=lambda x: x, 
            num_workers=0, 
            pin_memory=True
        )
        val_ood_loader = DataLoader(
            val_ood_dataset, 
            batch_size=batch_size, 
            shuffle=False, 
            collate_fn=lambda x: x, 
            num_workers=0, 
            pin_memory=True
        )

        # Load the base FLAVA model and processor
        model = FlavaForPreTraining.from_pretrained("facebook/flava-full")
        processor = FlavaProcessor.from_pretrained("facebook/flava-full")
        device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        model.to(device)

        # Apply LoRA
        lora_config = LoraConfig(
            r=lora_r[0],
            lora_alpha=lora_r[1],
            lora_dropout=0.5,
            bias="none",
            target_modules="all-linear"
        )
        peft_model = get_peft_model(model, lora_config)
        for name, param in peft_model.named_parameters():
            if "lora" not in name.lower():
                param.requires_grad = False
        model = peft_model
        model.to(device)

        # Set up optimizer
        optimizer = torch.optim.AdamW(
            filter(lambda p: p.requires_grad, model.parameters()), 
            lr=lr, 
            weight_decay=0.1
        )

        num_epochs = 15
        patience = 3
        epochs_no_improve = 0
        current_best_accuracy = 0.0
        train_losses = []

        for epoch in range(num_epochs):
            model.train()
            total_loss = 0.0
            for i, batch in enumerate(train_loader):
                images, texts_lists, correct_indices = zip(*batch)
                batch_logits = []
                for img, texts in zip(images, texts_lists):
                    sub_images = [img] * 5
                    sub_texts = texts
                    inputs = processor(
                        images=sub_images,
                        text=sub_texts,
                        return_tensors="pt",
                        padding=True,
                        truncation=True,
                        max_length=77,
                        return_codebook_pixels=True,
                        return_image_mask=True,
                        return_attention_mask=True
                    ).to(device)
                    outputs = model(**inputs)
                    logits = outputs.contrastive_logits_per_image[0]
                    batch_logits.append(logits)

                logits_per_image = torch.stack(batch_logits)
                correct_indices_tensor = torch.tensor(correct_indices, device=device)
                loss = nn.CrossEntropyLoss()(logits_per_image, correct_indices_tensor)
                total_loss += loss.item()

                optimizer.zero_grad()
                loss.backward()
                optimizer.step()

                if i % 10 == 0:
                    print(f"Epoch {epoch+1}, Batch {i}, Loss: {loss.item():.4f}")

            avg_loss = total_loss / len(train_loader)
            train_losses.append(avg_loss)
            print(f"Epoch {epoch+1} completed, Average Training Loss: {avg_loss:.4f}")

            # Validation phase
            model.eval()
            correct = 0
            total = 0
            with torch.no_grad():
                print("Start OOD Validation Phase")
                for batch_idx, batch in enumerate(val_ood_loader):
                    images, texts_lists, correct_indices = zip(*batch)
                    batch_logits = []
                    for img, texts in zip(images, texts_lists):
                        sub_images = [img] * 5
                        sub_texts = texts
                        inputs = processor(
                            images=sub_images,
                            text=sub_texts,
                            return_tensors="pt",
                            padding=True,
                            truncation=True,
                            max_length=77,
                            return_codebook_pixels=True,
                            return_image_mask=True,
                            return_attention_mask=True
                        ).to(device)
                        outputs = model(**inputs)
                        logits = outputs.contrastive_logits_per_image[0]
                        batch_logits.append(logits)

                    logits_per_image = torch.stack(batch_logits)
                    preds = logits_per_image.argmax(dim=1)
                    correct += (preds == torch.tensor(correct_indices, device=device)).sum().item()
                    total += len(images)

                accuracy_ood = correct / total
                print(f"Validation (OOD) Accuracy for {dataset_name}: {accuracy_ood:.4f}")

                # Save best model based on OOD validation
                if accuracy_ood > current_best_accuracy:
                    current_best_accuracy = accuracy_ood
                    epochs_no_improve = 0
                else:
                    epochs_no_improve += 1

                # Update global best model if current model is better
                if accuracy_ood > best_accuracy:
                    best_accuracy = accuracy_ood
                    best_hyperparams = {'batch_size': batch_size, 'lora_r': lora_r, 'lr': lr}
                    best_train_losses = train_losses.copy()
                    model_save_dir = '/home/bboulbarss/finetuned_models/flava'
                    os.makedirs(model_save_dir, exist_ok=True)
                    best_model_path = os.path.join(
                        model_save_dir, 
                        f'flava_lora_best_{dataset_name}_{seed}_{timestamp}_{lora_r}_{batch_size}_{lr}'
                    )
                    best_processor_path = os.path.join(
                        model_save_dir, 
                        f'flava_processor_best_{dataset_name}_{seed}_{timestamp}_{lora_r}_{batch_size}_{lr}'
                    )
                    model.save_pretrained(best_model_path)
                    processor.save_pretrained(best_processor_path)

            if epochs_no_improve >= patience:
                print(f"Early stopping at epoch {epoch+1}")
                break

    # Plot training loss curve for the best model
    plt.figure(figsize=(10, 6))
    plt.plot(range(1, len(best_train_losses) + 1), best_train_losses, marker='o', linestyle='-', color='b')
    plt.title(f'Training Loss Curve for Best Model\nDataset: {dataset_name}, '
              f'Hyperparameters: {best_hyperparams}')
    plt.xlabel('Epoch')
    plt.ylabel('Average Training Loss')
    plt.grid(True)
    plt.savefig(os.path.join(model_save_dir, f'training_loss_curve_{dataset_name}_{seed}_{timestamp}.png'))
    plt.close()

    print(f"\nBest Model Hyperparameters: {best_hyperparams}")
    print(f"Best Validation (OOD) Accuracy: {best_accuracy:.4f}")
    print(f"Best LoRA adapter saved to: {best_model_path}")
    print(f"Processor saved to: {best_processor_path}")
    print(f"Training loss curve saved to: {model_save_dir}/training_loss_curve_{dataset_name}_{seed}_{timestamp}.png")

# %%
datasets = ['single_object'] #'single_object', 'relational', 'two_object'
for dataset in datasets:
    print(f"\nTraining on {dataset}")
    train_and_evaluate(dataset, seed=42)
# Out:
# Training on single_object
#
# Testing hyperparameters: lora_r=(8, 16), lr=1e-06
# Epoch 1, Batch 0, Loss: 0.2084
# Epoch 1, Batch 10, Loss: 0.2734
# Epoch 1, Batch 20, Loss: 0.2240
# Epoch 1, Batch 30, Loss: 0.1402
# Epoch 1, Batch 40, Loss: 0.1245
# Epoch 1 completed, Average Training Loss: 0.2561
# Start OOD Validation Phase
# Validation (OOD) Accuracy for single_object: 0.9575
# Epoch 2, Batch 0, Loss: 0.0988
# Epoch 2, Batch 10, Loss: 0.2138
# Epoch 2, Batch 20, Loss: 0.1537
# Epoch 2, Batch 30, Loss: 0.1000
# Epoch 2, Batch 40, Loss: 0.3012
# Epoch 2 completed, Average Training Loss: 0.2291
# Start OOD Validation Phase
# Validation (OOD) Accuracy for single_object: 0.9375
# Epoch 3, Batch 0, Loss: 0.1387
# Epoch 3, Batch 10, Loss: 0.2206
# Epoch 3, Batch 20, Loss: 0.2276
# Epoch 3, Batch 30, Loss: 0.1804
# Epoch 3, Batch 40, Loss: 0.4410
# Epoch 3 completed, Average Training Loss: 0.2307
# Start OOD Validation Phase
# Validation (OOD) Accuracy for single_object: 0.9450
# Epoch 4, Batch 0, Loss: 0.2498
# Epoch 4, Batch 10, Loss: 0.2758
# Epoch 4, Batch 20, Loss: 0.1991
# Epoch 4, Batch 30, Loss: 0.1562
# Epoch 4, Batch 40, Loss: 0.3591
# Epoch 4 completed, Average Training Loss: 0.2026
# Start OOD Validation Phase
# Validation (OOD) Accuracy for single_object: 0.9475
# Early stopping at epoch 4
#
# Testing hyperparameters: lora_r=(8, 16), lr=1e-05
# Epoch 1, Batch 0, Loss: 0.1628
# Epoch 1, Batch 10, Loss: 0.1243
# Epoch 1, Batch 20, Loss: 0.2418
# Epoch 1, Batch 30, Loss: 0.1448
# Epoch 1, Batch 40, Loss: 0.3420
# Epoch 1 completed, Average Training Loss: 0.2053
# Start OOD Validation Phase
# Validation (OOD) Accuracy for single_object: 0.9400
# Epoch 2, Batch 0, Loss: 0.1364
# Epoch 2, Batch 10, Loss: 0.2707
# Epoch 2, Batch 20, Loss: 0.0976
# Epoch 2, Batch 30, Loss: 0.0895
# Epoch 2, Batch 40, Loss: 0.1369
# Epoch 2 completed, Average Training Loss: 0.0908
# Start OOD Validation Phase
# Validation (OOD) Accuracy for single_object: 0.9700
# Epoch 3, Batch 0, Loss: 0.0290
# Epoch 3, Batch 10, Loss: 0.0641
# Epoch 3, Batch 20, Loss: 0.0391
# Epoch 3, Batch 30, Loss: 0.0746
# Epoch 3, Batch 40, Loss: 0.0726
# Epoch 3 completed, Average Training Loss: 0.0578
# Start OOD Validation Phase
# Validation (OOD) Accuracy for single_object: 0.9600
# Epoch 4, Batch 0, Loss: 0.0288
# Epoch 4, Batch 10, Loss: 0.0426
# Epoch 4, Batch 20, Loss: 0.0195
# Epoch 4, Batch 30, Loss: 0.0285
# Epoch 4, Batch 40, Loss: 0.0384
# Epoch 4 completed, Average Training Loss: 0.0404
# Start OOD Validation Phase
# Validation (OOD) Accuracy for single_object: 0.9800
# Epoch 5, Batch 0, Loss: 0.0098
# Epoch 5, Batch 10, Loss: 0.0252
# Epoch 5, Batch 20, Loss: 0.0569
# Epoch 5, Batch 30, Loss: 0.0451
# Epoch 5, Batch 40, Loss: 0.0265
# Epoch 5 completed, Average Training Loss: 0.0254
# Start OOD Validation Phase
# Validation (OOD) Accuracy for single_object: 0.9725
# Epoch 6, Batch 0, Loss: 0.0416
# Epoch 6, Batch 10, Loss: 0.0410
# Epoch 6, Batch 20, Loss: 0.0222
# Epoch 6, Batch 30, Loss: 0.0059
# Epoch 6, Batch 40, Loss: 0.0110
# Epoch 6 completed, Average Training Loss: 0.0190
# Start OOD Validation Phase
# Validation (OOD) Accuracy for single_object: 0.9825
# Epoch 7, Batch 0, Loss: 0.0119
# Epoch 7, Batch 10, Loss: 0.0200
# Epoch 7, Batch 20, Loss: 0.0349
# Epoch 7, Batch 30, Loss: 0.0095
# Epoch 7, Batch 40, Loss: 0.0178
# Epoch 7 completed, Average Training Loss: 0.0140
# Start OOD Validation Phase
# Validation (OOD) Accuracy for single_object: 0.9875
# Epoch 8, Batch 0, Loss: 0.0132
# Epoch 8, Batch 10, Loss: 0.0222
# Epoch 8, Batch 20, Loss: 0.0154
# Epoch 8, Batch 30, Loss: 0.0083
# Epoch 8, Batch 40, Loss: 0.0090
# Epoch 8 completed, Average Training Loss: 0.0124
# Start OOD Validation Phase
# Validation (OOD) Accuracy for single_object: 0.9925
# Epoch 9, Batch 0, Loss: 0.0083
# Epoch 9, Batch 10, Loss: 0.0080
# Epoch 9, Batch 20, Loss: 0.0129
# Epoch 9, Batch 30, Loss: 0.0097
# Epoch 9, Batch 40, Loss: 0.0058
# Epoch 9 completed, Average Training Loss: 0.0095
# Start OOD Validation Phase
# Validation (OOD) Accuracy for single_object: 0.9825
# Epoch 10, Batch 0, Loss: 0.0039
# Epoch 10, Batch 10, Loss: 0.0155
# Epoch 10, Batch 20, Loss: 0.0075
# Epoch 10, Batch 30, Loss: 0.0029
# Epoch 10, Batch 40, Loss: 0.0159
# Epoch 10 completed, Average Training Loss: 0.0074
# Start OOD Validation Phase
# Validation (OOD) Accuracy for single_object: 0.9850
# Epoch 11, Batch 0, Loss: 0.0052
# Epoch 11, Batch 10, Loss: 0.0090
# Epoch 11, Batch 20, Loss: 0.0031
# Epoch 11, Batch 30, Loss: 0.0102
# Epoch 11, Batch 40, Loss: 0.0017
# Epoch 11 completed, Average Training Loss: 0.0073
# Start OOD Validation Phase
# Validation (OOD) Accuracy for single_object: 0.9900
# Early stopping at epoch 11
#
# Testing hyperparameters: lora_r=(16, 32), lr=1e-06
# Epoch 1, Batch 0, Loss: 0.5046
# Epoch 1, Batch 10, Loss: 0.1132
# Epoch 1, Batch 20, Loss: 0.3128
# Epoch 1, Batch 30, Loss: 0.4422
# Epoch 1, Batch 40, Loss: 0.2412
# Epoch 1 completed, Average Training Loss: 0.2626
# Start OOD Validation Phase
# Validation (OOD) Accuracy for single_object: 0.9425
# Epoch 2, Batch 0, Loss: 0.2066
# Epoch 2, Batch 10, Loss: 0.2363
# Epoch 2, Batch 20, Loss: 0.1439
# Epoch 2, Batch 30, Loss: 0.1720
# Epoch 2, Batch 40, Loss: 0.2340
# Epoch 2 completed, Average Training Loss: 0.2240
# Start OOD Validation Phase
# Validation (OOD) Accuracy for single_object: 0.9325
# Epoch 3, Batch 0, Loss: 0.1517
# Epoch 3, Batch 10, Loss: 0.0686
# Epoch 3, Batch 20, Loss: 0.1745
# Epoch 3, Batch 30, Loss: 0.1726
# Epoch 3, Batch 40, Loss: 0.1279
# Epoch 3 completed, Average Training Loss: 0.1739
# Start OOD Validation Phase
# Validation (OOD) Accuracy for single_object: 0.9250
# Epoch 4, Batch 0, Loss: 0.2607
# Epoch 4, Batch 10, Loss: 0.1274
# Epoch 4, Batch 20, Loss: 0.1648
# Epoch 4, Batch 30, Loss: 0.0258
# Epoch 4, Batch 40, Loss: 0.3073
# Epoch 4 completed, Average Training Loss: 0.1638
# Start OOD Validation Phase
# Validation (OOD) Accuracy for single_object: 0.9750
# Epoch 5, Batch 0, Loss: 0.1725
# Epoch 5, Batch 10, Loss: 0.0611
# Epoch 5, Batch 20, Loss: 0.1803
# Epoch 5, Batch 30, Loss: 0.1588
# Epoch 5, Batch 40, Loss: 0.1882
# Epoch 5 completed, Average Training Loss: 0.1673
# Start OOD Validation Phase
# Validation (OOD) Accuracy for single_object: 0.9500
# Epoch 6, Batch 0, Loss: 0.1641
# Epoch 6, Batch 10, Loss: 0.2011
# Epoch 6, Batch 20, Loss: 0.2235
# Epoch 6, Batch 30, Loss: 0.2282
# Epoch 6, Batch 40, Loss: 0.1971
# Epoch 6 completed, Average Training Loss: 0.1392
# Start OOD Validation Phase
# Validation (OOD) Accuracy for single_object: 0.9675
# Epoch 7, Batch 0, Loss: 0.0724
# Epoch 7, Batch 10, Loss: 0.1070
# Epoch 7, Batch 20, Loss: 0.1259
# Epoch 7, Batch 30, Loss: 0.0831
# Epoch 7, Batch 40, Loss: 0.1358
# Epoch 7 completed, Average Training Loss: 0.1205
# Start OOD Validation Phase
# Validation (OOD) Accuracy for single_object: 0.9575
# Early stopping at epoch 7
#
# Testing hyperparameters: lora_r=(16, 32), lr=1e-05
# Epoch 1, Batch 0, Loss: 0.2505
# Epoch 1, Batch 10, Loss: 0.2182
# Epoch 1, Batch 20, Loss: 0.1055
# Epoch 1, Batch 30, Loss: 0.1225
# Epoch 1, Batch 40, Loss: 0.0630
# Epoch 1 completed, Average Training Loss: 0.1446
# Start OOD Validation Phase
# Validation (OOD) Accuracy for single_object: 0.9750
# Epoch 2, Batch 0, Loss: 0.0320
# Epoch 2, Batch 10, Loss: 0.0958
# Epoch 2, Batch 20, Loss: 0.1251
# Epoch 2, Batch 30, Loss: 0.0223
# Epoch 2, Batch 40, Loss: 0.0284
# Epoch 2 completed, Average Training Loss: 0.0619
# Start OOD Validation Phase
# Validation (OOD) Accuracy for single_object: 0.9875
# Epoch 3, Batch 0, Loss: 0.0693
# Epoch 3, Batch 10, Loss: 0.0638
# Epoch 3, Batch 20, Loss: 0.0225
# Epoch 3, Batch 30, Loss: 0.0479
# Epoch 3, Batch 40, Loss: 0.0246
# Epoch 3 completed, Average Training Loss: 0.0311
# Start OOD Validation Phase
# Validation (OOD) Accuracy for single_object: 0.9825
# Epoch 4, Batch 0, Loss: 0.0083
# Epoch 4, Batch 10, Loss: 0.0177
# Epoch 4, Batch 20, Loss: 0.0050
# Epoch 4, Batch 30, Loss: 0.0137
# Epoch 4, Batch 40, Loss: 0.0154
# Epoch 4 completed, Average Training Loss: 0.0260
# Start OOD Validation Phase
# Validation (OOD) Accuracy for single_object: 0.9925
# Epoch 5, Batch 0, Loss: 0.0060
# Epoch 5, Batch 10, Loss: 0.0171
# Epoch 5, Batch 20, Loss: 0.0242
# Epoch 5, Batch 30, Loss: 0.0127
# Epoch 5, Batch 40, Loss: 0.0279
# Epoch 5 completed, Average Training Loss: 0.0149
# Start OOD Validation Phase
# Validation (OOD) Accuracy for single_object: 0.9825
# Epoch 6, Batch 0, Loss: 0.0179
# Epoch 6, Batch 10, Loss: 0.0051
# Epoch 6, Batch 20, Loss: 0.0061
# Epoch 6, Batch 30, Loss: 0.0139
# Epoch 6, Batch 40, Loss: 0.0068
# Epoch 6 completed, Average Training Loss: 0.0105
# Start OOD Validation Phase
# Validation (OOD) Accuracy for single_object: 0.9825
# Epoch 7, Batch 0, Loss: 0.0054
# Epoch 7, Batch 10, Loss: 0.0022
# Epoch 7, Batch 20, Loss: 0.0057
# Epoch 7, Batch 30, Loss: 0.0046
# Epoch 7, Batch 40, Loss: 0.0088
# Epoch 7 completed, Average Training Loss: 0.0083
# Start OOD Validation Phase
# Validation (OOD) Accuracy for single_object: 0.9925
# Early stopping at epoch 7
#
# Best Model Hyperparameters: {'batch_size': 32, 'lora_r': (8, 16), 'lr': 1e-05}
# Best Validation (OOD) Accuracy: 0.9925
# Best LoRA adapter saved to: /home/bboulbarss/finetuned_models/flava/flava_lora_best_single_object_42_20250523_122954_(8, 16)_32_1e-05
# Processor saved to: /home/bboulbarss/finetuned_models/flava/flava_processor_best_single_object_42_20250523_122954_(8, 16)_32_1e-05
# Training loss curve saved to: /home/bboulbarss/finetuned_models/flava/training_loss_curve_single_object_42_20250523_122954.png
